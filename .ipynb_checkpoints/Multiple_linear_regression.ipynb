# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter #for custom number format on x and y axis
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.formula.api as sm

# %%
import io
import requests
from zipfile import ZipFile
from IPython.display import display_html

# %%
print(f'pandas  version: {pd.__version__}')
print(f'numpy   version: {np.__version__}')
# Out:
# pandas  version: 1.4.2
# numpy   version: 1.22.4

# %%
## url='http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv'
#url='https://github.com/prasertcbs/basic-dataset/raw/master/ISLR/Advertising.csv'
## df=pd.read_csv(url, index_col=0)
#df=pd.read_csv(url, usecols=[1, 2, 3, 4])
## df=pd.read_csv(url, usecols=list(range(1, 5)))
#df.head()

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
covid = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv',parse_dates=['date']) #, index_col='Entity', parse_dates=True)
covid
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 196311      ZWE    Africa     Zimbabwe 2022-06-19     254801.0       48.0
# 196312      ZWE    Africa     Zimbabwe 2022-06-20     254831.0       30.0
# 196313      ZWE    Africa     Zimbabwe 2022-06-21     254919.0       88.0
# 196314      ZWE    Africa     Zimbabwe 2022-06-22     255049.0      130.0
# 196315      ZWE    Africa     Zimbabwe 2022-06-23     255136.0       87.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 196311             100.429        5534.0         1.0                1.857
# 196312              96.571        5534.0         0.0                1.857
# 196313             109.143        5536.0         2.0                2.143
# 196314              94.571        5541.0         5.0                2.286
# 196315              90.571        5542.0         1.0                2.286
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 196311  ...             1.6          30.7                  36.791
# 196312  ...             1.6          30.7                  36.791
# 196313  ...             1.6          30.7                  36.791
# 196314  ...             1.6          30.7                  36.791
# 196315  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 196311                         1.7            61.49                    0.571
# 196312                         1.7            61.49                    0.571
# 196313                         1.7            61.49                    0.571
# 196314                         1.7            61.49                    0.571
# 196315                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 196311                                   NaN                          NaN
# 196312                                   NaN                          NaN
# 196313                                   NaN                          NaN
# 196314                                   NaN                          NaN
# 196315                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 196311               NaN                                      NaN
# 196312               NaN                                      NaN
# 196313               NaN                                      NaN
# 196314               NaN                                      NaN
# 196315               NaN                                      NaN
#
# [196316 rows x 67 columns]

# %%
covid.shape
# Out:
# (196316, 67)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196316 entries, 0 to 196315
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    196316 non-null  object
#  1   continent                                   184930 non-null  object
#  2   location                                    196316 non-null  object
#  3   date                                        196316 non-null  datetime64[ns]
#  4   total_cases                                 188414 non-null  float64
#  5   new_cases                                   188185 non-null  float64
#  6   new_cases_smoothed                          187011 non-null  float64
#  7   total_deaths                                169827 non-null  float64
#  8   new_deaths                                  169821 non-null  float64
#  9   new_deaths_smoothed                         168658 non-null  float64
#  10  total_cases_per_million                     187546 non-null  float64
#  11  new_cases_per_million                       187317 non-null  float64
#  12  new_cases_smoothed_per_million              186148 non-null  float64
#  13  total_deaths_per_million                    168972 non-null  float64
#  14  new_deaths_per_million                      168966 non-null  float64
#  15  new_deaths_smoothed_per_million             167808 non-null  float64
#  16  reproduction_rate                           146820 non-null  float64
#  17  icu_patients                                26077 non-null   float64
#  18  icu_patients_per_million                    26077 non-null   float64
#  19  hosp_patients                               27315 non-null   float64
#  20  hosp_patients_per_million                   27315 non-null   float64
#  21  weekly_icu_admissions                       6374 non-null    float64
#  22  weekly_icu_admissions_per_million           6374 non-null    float64
#  23  weekly_hosp_admissions                      12722 non-null   float64
#  24  weekly_hosp_admissions_per_million          12722 non-null   float64
#  25  total_tests                                 79385 non-null   float64
#  26  new_tests                                   75401 non-null   float64
#  27  total_tests_per_thousand                    79385 non-null   float64
#  28  new_tests_per_thousand                      75401 non-null   float64
#  29  new_tests_smoothed                          103963 non-null  float64
#  30  new_tests_smoothed_per_thousand             103963 non-null  float64
#  31  positive_rate                               95920 non-null   float64
#  32  tests_per_case                              94058 non-null   float64
#  33  tests_units                                 106786 non-null  object
#  34  total_vaccinations                          54022 non-null   float64
#  35  people_vaccinated                           51468 non-null   float64
#  36  people_fully_vaccinated                     48966 non-null   float64
#  37  total_boosters                              25946 non-null   float64
#  38  new_vaccinations                            44280 non-null   float64
#  39  new_vaccinations_smoothed                   107376 non-null  float64
#  40  total_vaccinations_per_hundred              54022 non-null   float64
#  41  people_vaccinated_per_hundred               51468 non-null   float64
#  42  people_fully_vaccinated_per_hundred         48966 non-null   float64
#  43  total_boosters_per_hundred                  25946 non-null   float64
#  44  new_vaccinations_smoothed_per_million       107376 non-null  float64
#  45  new_people_vaccinated_smoothed              106415 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  106415 non-null  float64
#  47  stringency_index                            152593 non-null  float64
#  48  population                                  195131 non-null  float64
#  49  population_density                          174947 non-null  float64
#  50  median_age                                  162173 non-null  float64
#  51  aged_65_older                               160458 non-null  float64
#  52  aged_70_older                               161324 non-null  float64
#  53  gdp_per_capita                              161066 non-null  float64
#  54  extreme_poverty                             105125 non-null  float64
#  55  cardiovasc_death_rate                       161793 non-null  float64
#  56  diabetes_prevalence                         169702 non-null  float64
#  57  female_smokers                              122188 non-null  float64
#  58  male_smokers                                120513 non-null  float64
#  59  handwashing_facilities                      79377 non-null   float64
#  60  hospital_beds_per_thousand                  143575 non-null  float64
#  61  life_expectancy                             183607 non-null  float64
#  62  human_development_index                     157401 non-null  float64
#  63  excess_mortality_cumulative_absolute        6715 non-null    float64
#  64  excess_mortality_cumulative                 6715 non-null    float64
#  65  excess_mortality                            6715 non-null    float64
#  66  excess_mortality_cumulative_per_million     6715 non-null    float64
# dtypes: datetime64[ns](1), float64(62), object(4)
# memory usage: 100.4+ MB

# %%
#Save model to .csv
#data1.to_csv('D:/Face Detection/Datanew/data1.csv')
data = covid.loc[:,['date','location','total_cases','new_cases','total_deaths','life_expectancy','gdp_per_capita']].dropna() #คำสั่ง .loc ใช้เลือกข้อมูลบางคอลัมน์
data
# Out:
#              date     location  total_cases  new_cases  total_deaths  \
# 28     2020-03-23  Afghanistan         40.0        6.0           1.0
# 29     2020-03-24  Afghanistan         42.0        2.0           1.0
# 30     2020-03-25  Afghanistan         74.0       32.0           1.0
# 31     2020-03-26  Afghanistan         80.0        6.0           2.0
# 32     2020-03-27  Afghanistan         91.0       11.0           2.0
# ...           ...          ...          ...        ...           ...
# 196311 2022-06-19     Zimbabwe     254801.0       48.0        5534.0
# 196312 2022-06-20     Zimbabwe     254831.0       30.0        5534.0
# 196313 2022-06-21     Zimbabwe     254919.0       88.0        5536.0
# 196314 2022-06-22     Zimbabwe     255049.0      130.0        5541.0
# 196315 2022-06-23     Zimbabwe     255136.0       87.0        5542.0
#
#         life_expectancy  gdp_per_capita
# 28                64.83        1803.987
# 29                64.83        1803.987
# 30                64.83        1803.987
# 31                64.83        1803.987
# 32                64.83        1803.987
# ...                 ...             ...
# 196311            61.49        1899.775
# 196312            61.49        1899.775
# 196313            61.49        1899.775
# 196314            61.49        1899.775
# 196315            61.49        1899.775
#
# [144848 rows x 7 columns]

# %%
#data5 = data5.loc[:, ['Entity','Code','Year','Breast cancer (deaths)']]
#s = data1.drop([77,140,43,119]) #,axis=0).drop([60604]) #ลบแถว
df1 = data.loc[data['date'] == '2021-12-21'].sort_values(['total_deaths'],ascending=False) #.drop([147120]) #.rename(columns={'Internet':'y'}) #ข้อมูล ณ วันที่ 7 ธค.2020
df1
# Out:
#              date               location  total_cases  new_cases  \
# 193672 2021-12-21                  World  276620315.0   755765.0
# 185662 2021-12-21          United States   51339527.0   179413.0
# 25158  2021-12-21                 Brazil   22223943.0     3734.0
# 81752  2021-12-21                  India   34758481.0     6317.0
# 114679 2021-12-21                 Mexico    3934102.0        0.0
# ...           ...                    ...          ...        ...
# 80876  2021-12-21                Iceland      21215.0      325.0
# 148973 2021-12-21  Saint Kitts and Nevis       2809.0        1.0
# 33563  2021-12-21         Cayman Islands       8245.0      148.0
# 21004  2021-12-21                 Bhutan       2658.0        1.0
# 189619 2021-12-21                Vanuatu          7.0        0.0
#
#         total_deaths  life_expectancy  gdp_per_capita
# 193672     5375259.0            72.58       15469.207
# 185662      812577.0            78.86       54225.446
# 25158       618220.0            75.88       14103.452
# 81752       478325.0            69.66        6426.674
# 114679      297916.0            75.05       17336.469
# ...              ...              ...             ...
# 80876           37.0            82.99       46482.958
# 148973          28.0            76.23       24654.385
# 33563            9.0            83.92       49903.029
# 21004            3.0            71.78        8708.597
# 189619           1.0            70.47        2921.909
#
# [180 rows x 7 columns]

# %%
df2 = df1.sort_values(['total_deaths'],ascending=False).set_index('location').head(60) #.reset_index()
df2.head(60)
# Out:
#                              date  total_cases  new_cases  total_deaths  \
# location
# World                  2021-12-21  276620315.0   755765.0     5375259.0
# United States          2021-12-21   51339527.0   179413.0      812577.0
# Brazil                 2021-12-21   22223943.0     3734.0      618220.0
# India                  2021-12-21   34758481.0     6317.0      478325.0
# Mexico                 2021-12-21    3934102.0        0.0      297916.0
# Russia                 2021-12-21   10089945.0    25655.0      293329.0
# Peru                   2021-12-21    2267715.0     2395.0      202338.0
# United Kingdom         2021-12-21   11564446.0    89249.0      147543.0
# Indonesia              2021-12-21    4260893.0      216.0      144024.0
# Italy                  2021-12-21    5436143.0    30783.0      135931.0
# Iran                   2021-12-21    6175782.0     2413.0      131167.0
# Colombia               2021-12-21    5110788.0     1766.0      129534.0
# France                 2021-12-21    8758599.0    72857.0      122008.0
# Argentina              2021-12-21    5404380.0     9336.0      116953.0
# Germany                2021-12-21    6833050.0    23428.0      108814.0
# Ukraine                2021-12-21    3794490.0     6281.0       99528.0
# Ukraine                           72.06        7894.393
# Poland                            78.73       27216.445
# South Africa                      64.13       12294.876
# Spain                             83.56       34272.360
# Turkey                            77.69       25129.341
# Romania                           76.05       23313.199
# Chile                             80.18       22767.037
# Hungary                           76.88       26777.561
# Czechia                           79.38       32605.906
# Ecuador                           77.01       10581.936
# Malaysia                          76.16       26808.164
# Bulgaria                          75.05       18563.307
# Canada                            82.43       44017.591
# Vietnam                           75.40        6171.884
# Pakistan                          67.27        5034.708
# Bangladesh                        72.59        3523.984
# Belgium                           81.63       42658.576
# Tunisia                           76.70       10849.297
# Iraq                              70.60       15663.986
# Egypt                             71.99       10550.206
# Thailand                          77.15       16277.671
# Netherlands                       82.28       48472.545
# Greece                            82.24       24574.382
# Bolivia                           71.51        6885.829
# Myanmar                           67.13        5591.597
# Portugal                          82.05       27936.896
# Japan                             84.63       39002.223
# Kazakhstan                        73.60       24055.588
# Paraguay                          74.25        8827.010
# Austria                           81.54       45436.686
# Slovakia                          77.54       30155.152
# Guatemala                         74.30        7423.808
# Sweden                            82.80       46949.283
# Morocco                           76.68        7485.013
# Sri Lanka                         76.98       11669.077
# Bosnia and Herzegovina            77.40       11713.895
# Georgia                           73.77        9745.079
# Serbia                            76.00       14048.881
# Jordan                            74.53        8337.490
# Croatia                           78.49       22669.797
# Switzerland                       83.78       57410.166
# Nepal                             70.78        2442.804
# Honduras                          75.27        4541.795
# Moldova                           71.90        5189.972
# Lebanon                           78.93       13367.565

# %%
avg = df2['total_deaths'].mean() #.sum()/10
plt.axvline(avg, color='red', linestyle='--') 
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=18

ax = df2['total_deaths'].sort_values(ascending=True).plot(kind='barh',
                          figsize=(10, 30), #width, length
                          linewidth=25,
                          fontsize=18,
                          color=['green','red','black','c']);

ax.set_title('\n60 ປະເທດທີ່ມີຜູ້ເສຍຊີວິດຈາກການແພ່ລະບາດຂອງໂລກ ໂຄວິດ 19 ຫຼາຍທີ່ສຸດໃນໂລກ\n', 
             fontsize=20, color='blue')
ax.set_xlabel('\nປະຊາກອນເສີຍຊີວິດສະເລ່ຍ (----- ຄ່າສະເລ່ຍ = 27701.08)\n', fontsize=20, color='blue');

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.01, i.get_y()+.01, \
            str(round((i.get_width()), 2)), fontsize=18, color='blue')

# invert for largest on top 
#ax.invert_yaxis()

# %%
avg.round(2)
# Out:
# 173827.82

# %%
df3 = df1.sort_values(['total_deaths'],ascending=False).set_index('location').tail(30) #.reset_index()
df3
# Out:
#                                        date  total_cases  new_cases  \
# location
# Hong Kong                        2021-12-21      12541.0        8.0
# Grenada                          2021-12-21       5921.0        1.0
# Djibouti                         2021-12-21      13546.0        8.0
# Chad                             2021-12-21       5703.0        0.0
# Aruba                            2021-12-21      16920.0       72.0
# Equatorial Guinea                2021-12-21      13618.0        0.0
# Benin                            2021-12-21      24907.0        0.0
# Comoros                          2021-12-21       4677.0        0.0
# Guinea-Bissau                    2021-12-21       6458.0        2.0
# South Sudan                      2021-12-21      13831.0      217.0
# Seychelles                       2021-12-21      24152.0       24.0
# Tajikistan                       2021-12-21      17493.0        0.0
# Timor                            2021-12-21      19833.0        0.0
# Sierra Leone                     2021-12-21       6525.0       15.0
# Antigua and Barbuda              2021-12-21       4201.0        3.0
# Bermuda                          2021-12-21       5917.0        0.0
# Central African Republic         2021-12-21      11961.0        0.0
# Brunei                           2021-12-21      15418.0        6.0
# San Marino                       2021-12-21       7160.0        0.0
# Saint Vincent and the Grenadines 2021-12-21       5784.0       26.0
# Eritrea                          2021-12-21       7807.0       28.0
# Sao Tome and Principe            2021-12-21       3736.0        1.0
# New Zealand                      2021-12-21      13589.0       58.0
# Dominica                         2021-12-21       6430.0        0.0
# Burundi                          2021-12-21      23009.0      370.0
# Iceland                          2021-12-21      21215.0      325.0
# Saint Kitts and Nevis            2021-12-21       2809.0        1.0
# Cayman Islands                   2021-12-21       8245.0      148.0
# Bhutan                           2021-12-21       2658.0        1.0
# Vanuatu                          2021-12-21          7.0        0.0
#
#                                   total_deaths  life_expectancy  \
# location
# Hong Kong                                213.0            84.86
# Grenada                                  200.0            72.40
# Djibouti                                 189.0            67.11
# Chad                                     181.0            54.24
# Aruba                                    180.0            76.29
# Equatorial Guinea                        175.0            58.74
# Benin                                    161.0            61.77
# Comoros                                  152.0            64.32
# Guinea-Bissau                            149.0            58.32
# South Sudan                              133.0            57.85
# Seychelles                               131.0            73.40
# Tajikistan                               125.0            71.10
# Timor                                    122.0            69.50
# Sierra Leone                             121.0            54.70
# Antigua and Barbuda                      117.0            77.02
# Bermuda                                  106.0            82.59
# Central African Republic                 101.0            53.28
# Brunei                                    98.0            75.86
# San Marino                                96.0            84.97
# Saint Vincent and the Grenadines          79.0            72.53
# Eritrea                                   70.0            66.32
# Sao Tome and Principe                     57.0            70.39
# New Zealand                               49.0            82.29
# Dominica                                  44.0            75.00
# Burundi                                   38.0            61.58
# Iceland                                   37.0            82.99
# Saint Kitts and Nevis                     28.0            76.23
# Cayman Islands                             9.0            83.92
# Bhutan                                     3.0            71.78
# Vanuatu                                    1.0            70.47
#
#                                   gdp_per_capita
# location
# Hong Kong                              56054.920
# Grenada                                13593.877
# Djibouti                                2705.406
# Chad                                    1768.153
# Aruba                                  35973.781
# Equatorial Guinea                      22604.873
# Benin                                   2064.236
# Comoros                                 1413.890
# Guinea-Bissau                           1548.675
# South Sudan                             1569.888
# Seychelles                             26382.287
# Tajikistan                              2896.913
# Timor                                   6570.102
# Sierra Leone                            1390.300
# Antigua and Barbuda                    21490.943
# Bermuda                                50669.315
# Central African Republic                 661.240
# Brunei                                 71809.251
# San Marino                             56861.470
# Saint Vincent and the Grenadines       10727.146
# Eritrea                                 1510.459
# Sao Tome and Principe                   3052.714
# New Zealand                            36085.843
# Dominica                                9673.367
# Burundi                                  702.225
# Iceland                                46482.958
# Saint Kitts and Nevis                  24654.385
# Cayman Islands                         49903.029
# Bhutan                                  8708.597
# Vanuatu                                 2921.909

# %%
avg = df3['total_deaths'].mean() #.sum()/10
plt.axvline(avg, color='red', linestyle='--') 
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=18

ax = df3['total_deaths'].sort_values(ascending=True).plot(kind='barh',
                          figsize=(10, 15), #width, length
                          linewidth=25,
                          fontsize=18,
                          color=['green','red','black','c']);

ax.set_title('\n30 ປະເທດທີ່ມີຜູ້ເສຍຊີວິດຈາກການແພ່ລະບາດຂອງໂລກ ໂຄວິດ 19 ໜ້ອຍທີ່ສຸດໃນໂລກ\n', 
             fontsize=20, color='blue')
ax.set_xlabel('\nປະຊາກອນເສີຍຊີວິດສະເລ່ຍ (----- ຄ່າສະເລ່ຍ = 35.5)\n', fontsize=20, color='blue');
ax.set_ylabel('ປະເທດ\n', fontsize=20, color='blue');

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.01, i.get_y()+.01, \
            str(round((i.get_width()), 2)), fontsize=18, color='blue')

# invert for largest on top 
ax.invert_yaxis()
# Out:
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3739 (\N{LAO LETTER PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3760 (\N{LAO VOWEL SIGN A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3776 (\N{LAO VOWEL SIGN E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3735 (\N{LAO LETTER THO TAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3732 (\N{LAO LETTER DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3765 (\N{LAO VOWEL SIGN II}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3784 (\N{LAO TONE MAI EK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3745 (\N{LAO LETTER MO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3740 (\N{LAO LETTER PHO SUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3769 (\N{LAO VOWEL SIGN UU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3785 (\N{LAO TONE MAI THO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3754 (\N{LAO LETTER SO SUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3725 (\N{LAO LETTER NYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3722 (\N{LAO LETTER SO TAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3751 (\N{LAO LETTER WO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3764 (\N{LAO VOWEL SIGN I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3720 (\N{LAO LETTER CO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3762 (\N{LAO VOWEL SIGN AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3713 (\N{LAO LETTER KO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3737 (\N{LAO LETTER NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3777 (\N{LAO VOWEL SIGN EI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3742 (\N{LAO LETTER PHO TAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3749 (\N{LAO LETTER LO LOOT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3738 (\N{LAO LETTER BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3714 (\N{LAO LETTER KHO SUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3757 (\N{LAO LETTER O}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3719 (\N{LAO LETTER NGO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3778 (\N{LAO VOWEL SIGN O}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3716 (\N{LAO LETTER KHO TAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3804 (\N{LAO HO NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3768 (\N{LAO VOWEL SIGN U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3779 (\N{LAO VOWEL SIGN AY}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
avg
# Out:
# 105.5

# %%
# 10 Countries in AEC
AEC = df1.loc[df1['location'].isin(['Singapore','Indonesia','Thailand','Myanmar','Vietnam','Brunei','Laos','Cambodia','Malaysia','Philippines'])].set_index('location') #.reset_index() 
AEC
# Out:
#                 date  total_cases  new_cases  total_deaths  life_expectancy  \
# location
# Indonesia 2021-12-21    4260893.0      216.0      144024.0            71.72
# Malaysia  2021-12-21    2724684.0     3140.0       31192.0            76.16
# Vietnam   2021-12-21    1571780.0    16325.0       30041.0            75.40
# Thailand  2021-12-21    2196529.0     2476.0       21440.0            77.15
# Myanmar   2021-12-21     528639.0      259.0       19230.0            67.13
# Cambodia  2021-12-21     120427.0        4.0        3005.0            69.82
# Singapore 2021-12-21     276385.0      280.0         817.0            83.62
# Laos      2021-12-21     100524.0     1128.0         284.0            67.92
# Brunei    2021-12-21      15418.0        6.0          98.0            75.86
#
#            gdp_per_capita
# location
# Indonesia       11188.744
# Malaysia        26808.164
# Vietnam          6171.884
# Thailand        16277.671
# Myanmar          5591.597
# Cambodia         3645.070
# Singapore       85535.383
# Laos             6397.360
# Brunei          71809.251

# %%
avg = AEC['total_deaths'].mean() #.sum()/10
plt.axvline(avg, color='red', linestyle='--') 
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=18

ax = AEC['total_deaths'].sort_values(ascending=True).plot(kind='barh',
                          figsize=(8, 5), #width, length
                          linewidth=25,
                          fontsize=18,
                          color=['green','red','black','c']);

ax.set_title('\n ກຸ່ມປະເທດ AEC ທີ່ມີຜູ້ເສີຍຊີວິດຈາກການແພ່ລະບາດຂອງໂລກໂຄວິດ 19\n', 
             fontsize=20, color='blue')
ax.set_xlabel('\nປະຊາກອນເສີຍຊີວິດສະເລ່ຍ (----- ຄ່າສເລ່ຍ = 4041.0)\n', fontsize=20, color='blue');
ax.set_ylabel('ປະເທດ\n', fontsize=20, color='blue');

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.01, i.get_y()+.01, \
            str(round((i.get_width()), 2)), fontsize=18, color='blue')

# invert for largest on top 
#ax.invert_yaxis()

# %%
avg
# Out:
# 30092.5

# %% [markdown]
# ## sklearn: train_test_split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## method 1: split into (train, test)

# %%
# 10 Countries in AEC
df = data.loc[data['location'].isin(['United States'])] #.set_index('location') #.reset_index() 
df
# Out:
#              date       location  total_cases  new_cases  total_deaths  \
# 140924 2020-02-29  United States         25.0        8.0           1.0
# 140925 2020-03-01  United States         32.0        7.0           1.0
# 140926 2020-03-02  United States         55.0       23.0           6.0
# 140927 2020-03-03  United States         74.0       19.0           7.0
# 140928 2020-03-04  United States        107.0       33.0          11.0
# ...           ...            ...          ...        ...           ...
# 141581 2021-12-17  United States   50705659.0   189194.0      805823.0
# 141582 2021-12-18  United States   50776013.0    70354.0      806302.0
# 141583 2021-12-19  United States   50846828.0    70815.0      806439.0
# 141584 2021-12-20  United States   51100782.0   253954.0      807952.0
# 141585 2021-12-21  United States   51272854.0   172072.0      810045.0
#
#         life_expectancy  gdp_per_capita
# 140924            78.86       54225.446
# 140925            78.86       54225.446
# 140926            78.86       54225.446
# 140927            78.86       54225.446
# 140928            78.86       54225.446
# ...                 ...             ...
# 141581            78.86       54225.446
# 141582            78.86       54225.446
# 141583            78.86       54225.446
# 141584            78.86       54225.446
# 141585            78.86       54225.446
#
# [662 rows x 7 columns]

# %%
len(df) #ฟังก์ชัน len ใช้นับจำนวนแถว
# Out:
# 662

# %%
train, test = train_test_split(df, train_size=0.7, random_state=7)
# train, test = train_test_split(df, test_size=0.3)

# %%
print(len(train))
print(len(test))
# Out:
# 463
# 199

# %%
train #.head()
# Out:
#              date       location  total_cases  new_cases  total_deaths  \
# 141355 2021-05-05  United States   32636178.0    45704.0      578611.0
# 141318 2021-03-29  United States   30404464.0    67297.0      549429.0
# 141316 2021-03-27  United States   30290813.0    62223.0      548325.0
# 141275 2021-02-14  United States   27777969.0    66349.0      486897.0
# 140949 2020-03-25  United States      68841.0    12127.0        1366.0
# ...           ...            ...          ...        ...           ...
# 141503 2021-09-30  United States   43503491.0   109957.0      699572.0
# 141426 2021-07-15  United States   34062009.0    29908.0      608002.0
# 141461 2021-08-19  United States   37479308.0   157238.0      626348.0
# 141120 2020-09-12  United States    6488439.0    41688.0      193488.0
# 141099 2020-08-22  United States    5666888.0    44404.0      176052.0
#
#         life_expectancy  gdp_per_capita
# 141355            78.86       54225.446
# 141318            78.86       54225.446
# 141316            78.86       54225.446
# 141275            78.86       54225.446
# 140949            78.86       54225.446
# ...                 ...             ...
# 141503            78.86       54225.446
# 141426            78.86       54225.446
# 141461            78.86       54225.446
# 141120            78.86       54225.446
# 141099            78.86       54225.446
#
# [463 rows x 7 columns]

# %%
test.head()
# Out:
#              date       location  total_cases  new_cases  total_deaths  \
# 141519 2021-10-16  United States   44959223.0    34620.0      725818.0
# 141077 2020-07-31  United States    4566405.0    68469.0      153828.0
# 141471 2021-08-29  United States   38923484.0    42316.0      637666.0
# 141213 2020-12-14  United States   16672774.0   200628.0      305114.0
# 141335 2021-04-15  United States   31569745.0    73910.0      564600.0
#
#         life_expectancy  gdp_per_capita
# 141519            78.86       54225.446
# 141077            78.86       54225.446
# 141471            78.86       54225.446
# 141213            78.86       54225.446
# 141335            78.86       54225.446

# %% [markdown]
# ## method 2: split into (X_train, X_test, y_train, y_test)

# %%
df.columns
# Out:
# Index(['date', 'location', 'total_cases', 'new_cases', 'total_deaths',
#        'life_expectancy', 'gdp_per_capita'],
#       dtype='object')

# %%
X=df[['total_cases','new_cases','gdp_per_capita','life_expectancy']]
y=df['total_deaths']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.3, 
                                                    random_state=7)

# %%
X_train.head()
# Out:
#         total_cases  new_cases  gdp_per_capita  life_expectancy
# 141355   32636178.0    45704.0       54225.446            78.86
# 141318   30404464.0    67297.0       54225.446            78.86
# 141316   30290813.0    62223.0       54225.446            78.86
# 141275   27777969.0    66349.0       54225.446            78.86
# 140949      68841.0    12127.0       54225.446            78.86

# %%
X_test.head()
# Out:
#         total_cases  new_cases  gdp_per_capita  life_expectancy
# 141519   44959223.0    34620.0       54225.446            78.86
# 141077    4566405.0    68469.0       54225.446            78.86
# 141471   38923484.0    42316.0       54225.446            78.86
# 141213   16672774.0   200628.0       54225.446            78.86
# 141335   31569745.0    73910.0       54225.446            78.86

# %%
y_train.head()
# Out:
# 141355    578611.0
# 141318    549429.0
# 141316    548325.0
# 141275    486897.0
# 140949      1366.0
# Name: total_deaths, dtype: float64

# %%
y_test.head()
# Out:
# 141519    725818.0
# 141077    153828.0
# 141471    637666.0
# 141213    305114.0
# 141335    564600.0
# Name: total_deaths, dtype: float64

# %% [markdown]
# ## Scikit-Learn: LinearRegression

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
print(f'sklearn version: {sklearn.__version__}')
# Out:
# sklearn version: 1.0.1

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train, y_train) # R-squared
# Out:
# 0.9892144707180802

# %%
model.intercept_
# Out:
# 72857.77945299033

# %%
model.coef_
# Out:
# array([ 1.51777032e-02, -8.99367808e-02, -3.81824095e-34,  0.00000000e+00])

# %%
X_train.head().reset_index() #ใช้เรียงลำดับข้อ โดยเริ่มจาก 0 ถึงตัวสุดท้าย
# Out:
#     index  total_cases  new_cases  gdp_per_capita  life_expectancy
# 0  141355   32636178.0    45704.0       54225.446            78.86
# 1  141318   30404464.0    67297.0       54225.446            78.86
# 2  141316   30290813.0    62223.0       54225.446            78.86
# 3  141275   27777969.0    66349.0       54225.446            78.86
# 4  140949      68841.0    12127.0       54225.446            78.86

# %%
len(X_train)
# Out:
# 463

# %%
X_train[0:1].reset_index() #ใช้เรียงลำดับข้อ โดยเริ่มจาก 0 ถึงตัวสุดท้าย
# Out:
#     index  total_cases  new_cases  gdp_per_capita  life_expectancy
# 0  141355   32636178.0    45704.0       54225.446            78.86

# %% [markdown]
# ## การแปลงค่าให้เป็นอาเรย์
# ### วิธีที่ 1

# %%
np.array(X_train[0:1])
# Out:
# array([[3.2636178e+07, 4.5704000e+04, 5.4225446e+04, 7.8860000e+01]])

# %% [markdown]
# ### วิธีที่ 2 ใช้ ฟังก์ชัน method values

# %%
X_train[0:1].values
# Out:
# array([[3.2636178e+07, 4.5704000e+04, 5.4225446e+04, 7.8860000e+01]])

# %%
model.predict(X_train[0:1])
# Out:
# array([564089.53358583])

# %% [markdown]
# ## การพยากรณ์/ทำนายข้อมูลหลายแถว หลายคอลัมน์

# %%
X_train[0:5].reset_index()
# Out:
#     index  total_cases  new_cases  gdp_per_capita  life_expectancy
# 0  141355   32636178.0    45704.0       54225.446            78.86
# 1  141318   30404464.0    67297.0       54225.446            78.86
#        623169.84527717, 532107.1920918 , 161101.0155587 , 481029.14936611,
#        769323.90789525, 177482.45682944, 723251.67740337, 587151.01477185,
#        627566.11459838, 167588.09660615, 154874.57103022])

# %%
train=pd.concat([X_train, y_train], axis='columns')

# %%
train.head()
# Out:
#         total_cases  new_cases  gdp_per_capita  life_expectancy  total_deaths
# 141355   32636178.0    45704.0       54225.446            78.86      578611.0
# 141318   30404464.0    67297.0       54225.446            78.86      549429.0
# 141316   30290813.0    62223.0       54225.446            78.86      548325.0
# 141275   27777969.0    66349.0       54225.446            78.86      486897.0
# 140949      68841.0    12127.0       54225.446            78.86        1366.0

# %%
dc=pd.concat([train.reset_index(), pd.Series(y_hat, name='predicted')], axis='columns')
dc.head()
# Out:
#     index  total_cases  new_cases  gdp_per_capita  life_expectancy  \
# 0  141355   32636178.0    45704.0       54225.446            78.86
# 1  141318   30404464.0    67297.0       54225.446            78.86
# 2  141316   30290813.0    62223.0       54225.446            78.86
# 3  141275   27777969.0    66349.0       54225.446            78.86
# 4  140949      68841.0    12127.0       54225.446            78.86
#
#    total_deaths      predicted
# 0      578611.0  564089.533586
# 1      549429.0  528275.235857
# 2      548325.0  527006.613931
# 3      486897.0  488496.334238
# 4        1366.0   72811.964382

# %%
y_hat_test=model.predict(X_test)
y_hat_test
# Out:
# array([752121.91295905, 136007.43799948, 659821.10408284, 307868.35905379,
#        545366.77314136, 457423.2752623 , 125727.98272362, 775824.38369893,
#        575794.76413479, 760397.33767889, 175286.62963345, 218844.79208116,
#        584217.0654063 , 166324.91386845, 784922.96251347, 706269.50346114,
#        550850.08492645, 333982.74893008, 530356.64325709, 529734.73794645,
#        587603.85620398, 815803.48914088, 120393.12256831, 515341.34584805,
#        517256.69812337, 192257.14928937, 751246.30204405, 571108.54404264,
#        612451.21014424, 558250.5751662 , 170562.11652361, 804452.29598649,
#         85299.93659922, 563836.90180966, 172728.26558587, 565316.23832755,
#        182690.62099985, 589258.40062047,  90693.61659501, 496957.04712581,
#        583381.36053311, 194054.9458974 , 123559.02480991, 579483.04818185,
#        520908.1516164 , 568489.33110532, 203880.04732643, 721014.05697955,
#        505302.7296776 , 553957.82372863, 825610.47905043, 180409.15135769,
#        187822.64227268, 194058.56968678, 100701.11200382, 582286.48540358,
#        519589.1374364 , 124702.85105795, 512749.04499367, 536532.7157074 ,
#        614857.7969782 , 721711.91251106, 355688.33218199, 689896.45274574,
#        689621.85952679, 511264.39164975, 291908.98261205, 577328.37482216,
#         83182.96144761, 753998.49099554, 103541.66243397, 139623.3665111 ,
#        761780.58319097,  72586.00296736, 325170.61575466, 396146.30746487,
#        584080.25108551, 579413.79305372, 283587.09655551, 157257.23764994,
#        103195.18722558, 149838.04484825, 182928.53661582, 261815.71953026,
#        232344.89019975, 512213.80337913,  92280.18769922, 170058.89917246,
#        590619.71140144, 543354.66595508, 353460.89670144, 582081.66740223,
#        562500.76543757, 100162.17734138, 268250.99334774, 359305.82362321,
#        575375.40346886,  80429.01479027, 311288.94117815, 128699.58141773,
#        523421.60371622, 117706.43183432, 551864.41554826, 105149.20596639,
#        166596.40740878, 252177.22483407, 629249.3452824 , 161924.81230661,
#        209060.89870073, 587642.05284881, 178153.33955608, 777115.58505974,
#        115215.90574174, 201661.52466045, 534605.04725156,  83922.50072043,
#        786179.83751839, 644242.73720092,  72834.52879425, 542525.88155115,
#        708851.91571447, 132187.02395768,  86462.51325087, 837193.62449766,
#        521614.29117968, 103098.76068317, 816594.35846777, 162463.73674193,
#        404676.39269837,  72857.1938042 , 422674.72468441, 101255.06953195,
#        799533.06690664, 183130.39766405, 255425.0113577 ,  83028.6531966 ,
#         72791.76253734, 513765.18853783,  82203.19285517, 752909.32085312,
#        141852.48773958, 522868.25851876, 473422.44916875, 761801.70086232,
#        677881.4404144 , 672715.18851016,  73380.23508384, 444150.58394667,
#        212465.95164279, 784786.94923322, 105788.16192337, 490944.07008423,
#        613597.44684862, 586509.86850547, 811851.04554627,  82315.77460209,
#        779216.51301109, 224613.72209232, 438728.31134169, 350558.61094922,
#        575518.95848039, 602269.6111436 , 578416.85393983,  85911.96022717,
#        835586.34028783, 677206.05869759, 594253.41717296,  99505.88671839,
#        743431.68597368, 751689.32320188, 576597.51453945, 407551.60247702,
#         72554.43588246, 366472.48561672, 558801.10593584, 166367.58416449,
#        137744.66567003, 690016.98354189, 658276.09970339, 200630.63183884,
#        476532.11648572, 205352.00674981, 712674.8053515 , 583061.255668  ,
#         72856.54568071, 198748.07524631, 790357.43321395,  94629.9418427 ,
#        509076.40558881, 768359.58523109, 285325.89260768, 734713.88592879,
#         76397.27986488, 585578.834135  , 490378.48943262, 801418.81574093,
#         72852.74030214,  87715.92381328,  73363.46292741])

# %%
test=pd.concat([X_test, y_test], axis='columns')
test.head()
# Out:
#         total_cases  new_cases  gdp_per_capita  life_expectancy  total_deaths
# 141519   44959223.0    34620.0       54225.446            78.86      725818.0
# 141077    4566405.0    68469.0       54225.446            78.86      153828.0
# 141471   38923484.0    42316.0       54225.446            78.86      637666.0
# 141213   16672774.0   200628.0       54225.446            78.86      305114.0
# 141335   31569745.0    73910.0       54225.446            78.86      564600.0

# %%
dt=pd.concat([test.reset_index(), pd.Series(y_hat_test, name='predicted')], axis='columns')
dt.head()
# Out:
#     index  total_cases  new_cases  gdp_per_capita  life_expectancy  \
# 0  141519   44959223.0    34620.0       54225.446            78.86
# 1  141077    4566405.0    68469.0       54225.446            78.86
# 2  141471   38923484.0    42316.0       54225.446            78.86
# 3  141213   16672774.0   200628.0       54225.446            78.86
# 4  141335   31569745.0    73910.0       54225.446            78.86
#
#    total_deaths      predicted
# 0      725818.0  752121.912959
# 1      153828.0  136007.437999
# 2      637666.0  659821.104083
# 3      305114.0  307868.359054
# 4      564600.0  545366.773141

# %%
dt.corr()
# Out:
#                     index  total_cases  new_cases  gdp_per_capita  \
# index            1.000000     0.984730   0.314850             NaN
# total_cases      0.984730     1.000000   0.278225             NaN
# new_cases        0.314850     0.278225   1.000000             NaN
# gdp_per_capita        NaN          NaN        NaN             NaN
# life_expectancy       NaN          NaN        NaN             NaN
# total_deaths     0.988288     0.994551   0.253725             NaN
# predicted        0.983439     0.999717   0.255297             NaN
#
#                  life_expectancy  total_deaths  predicted
# index                        NaN      0.988288   0.983439
# total_cases                  NaN      0.994551   0.999717
# new_cases                    NaN      0.253725   0.255297
# gdp_per_capita               NaN           NaN        NaN
# life_expectancy              NaN           NaN        NaN
# total_deaths                 NaN      1.000000   0.994839
# predicted                    NaN      0.994839   1.000000

# %% [markdown]
# ## Statsmodels: Simple Linear regression

# %%
train, test = train_test_split(df, train_size=0.7, random_state=7)
# train, test = train_test_split(df, test_size=0.3)

# %%
train.head()
# Out:
#              date       location  total_cases  new_cases  total_deaths  \
# 141355 2021-05-05  United States   32636178.0    45704.0      578611.0
# 141318 2021-03-29  United States   30404464.0    67297.0      549429.0
# 141316 2021-03-27  United States   30290813.0    62223.0      548325.0
# 141275 2021-02-14  United States   27777969.0    66349.0      486897.0
# 140949 2020-03-25  United States      68841.0    12127.0        1366.0
#
#         life_expectancy  gdp_per_capita
# 141355            78.86       54225.446
# 141318            78.86       54225.446
# 141316            78.86       54225.446
# 141275            78.86       54225.446
# 140949            78.86       54225.446

# %%
test.head()
# Out:
#              date       location  total_cases  new_cases  total_deaths  \
# 141519 2021-10-16  United States   44959223.0    34620.0      725818.0
# 141077 2020-07-31  United States    4566405.0    68469.0      153828.0
# 141471 2021-08-29  United States   38923484.0    42316.0      637666.0
# 141213 2020-12-14  United States   16672774.0   200628.0      305114.0
# 141335 2021-04-15  United States   31569745.0    73910.0      564600.0
#
#         life_expectancy  gdp_per_capita
# 141519            78.86       54225.446
# 141077            78.86       54225.446
# 141471            78.86       54225.446
# 141213            78.86       54225.446
# 141335            78.86       54225.446

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# formula: response ~ predictor1 + predictor2
model_a = smf.ols(formula='total_deaths ~ total_cases + new_cases + gdp_per_capita + life_expectancy', data=train).fit()
# model_a = smf.ols(formula='Sales ~ TV + Radio', data=df).fit()

# %%
print(model_a.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           total_deaths   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                 2.109e+04
# Date:                Wed, 22 Dec 2021   Prob (F-statistic):               0.00
# Time:                        12:56:15   Log-Likelihood:                -5361.8
# No. Observations:                 463   AIC:                         1.073e+04
# Df Residuals:                     460   BIC:                         1.074e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        2.478e-05   7.56e-07     32.758      0.000    2.33e-05    2.63e-05
# total_cases         0.0152   7.64e-05    198.682      0.000       0.015       0.015
# new_cases          -0.0899      0.020     -4.601      0.000      -0.128      -0.052
# gdp_per_capita      1.3436      0.041     32.758      0.000       1.263       1.424
# life_expectancy     0.0020   5.96e-05     32.758      0.000       0.002       0.002
# ==============================================================================
# Omnibus:                       96.064   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              155.431
# Skew:                          -1.297   Prob(JB):                     1.77e-34
# Kurtosis:                       4.151   Cond. No.                     3.49e+23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### ถ้าค่า p (P>|t|) < 0.05 แสดงว่ามีความสัมพันธ์กัน คือคือตัวแปรต้น (X หรือเหตุ) เป็นสาเหตุ/ส่งผลต่อตัวแปรตาม (Y หรือผล) เช่น กินจุ (เหตุ) ทำให้อ้วน (ผล) ขณะเดียวกัน อ้วน (เหตุ) ทำให้เป็นโรคความดัน เบาหวาน (ผล) เป็นต้น
# ### ถ้าค่า p (P>|t|) > 0.05 แสดงว่าไม่มีความสัมพันธ์กัน คือคือตัวแปรต้น (X หรือเหตุ) ไม่เป็นสาเหตุ/ไม่ส่งผลต่อตัวแปรตาม (Y หรือผล) เช่น กินจุ (เหตุ) แต่ก็ไม่ทำให้อ้วน (ผล) ขณะเดียวกัน อ้วน (เหตุ) ไม่ทำให้เป็นโรคความดัน เบาหวาน (ผล) เป็นต้น
# ### ค่าอย่างมีนัยสำคัญทางสถิติที่..... ถ้าค่า p < 0.05 แต่ > 0.01 อย่างมีนัยสำคัญทางสถิติที่ 0.05, ถ้าค่า p < 0.01 แต่ > 0.001 อย่างมีนัยสำคัญทางสถิติที่ 0.01, ถ้าค่า p < 0.001 อย่างมีนัยสำคัญทางสถิติที่ 0.000

# %% [markdown]
# ### การอธิบายค่าสัมประสิทธิ์ถดถอย (coef) ถ้าค่าเป็นบวก (18.7179) หมายความว่า x1 (ตัวแปรอิสระ/ต้น: เหตุ) เพิ่มขึ้น ส่งผลให้ Y (ตัวแปรตาม: ผล) เพิ่มตามไปด้วย ขณะเดียวกัน ถ้าค่าเป็นลบ (-22.6050) หมายความว่า x1 (ตัวแปรอิสระ: เหตุ) เพิ่มขึ้น ส่งผลให้ Y (ตัวแปรตาม: ผล) ลดลง แต่ค่าลบในที่นี้ไม่ต้องนำมาอธิบาย เพราะไม่มีนัยสำคัญ คือค่า p > 0.05

# %% [markdown]
# ### แบบจำลองในการศึกษา
# ### Y = a + b1x1 + b2x2 + b3x3 + e
# ### กำหนดให้
# #### a = ค่าคงที่ความถดถอยพหุ
# #### b1 ... b5 = ค่าสัมประสิทธิถดถอยของตัวแปรอิสระ (ตัวแปรต้น)
# #### Y = total_deaths
# #### x1 = aged_65_older
# #### x2 = aged_70_older
# #### x3 = life_expectancy
# #### e = ค่าความคลาดเคลื่อน

# %% [markdown]
# ### การอธิบายแปลผล เอาเฉพาะตัวที่มีนัยสำคัญทางสถิติ คือค่า p < 0.05 เท่านั้นมาอธิบายแปลผล
# ### ผลการศึกษาพบว่า aged_65_older (x1) มีความสัมพันธ์ในทิศทางบวกกับ total_deaths (Y) ที่ระดับนัยสำคัญทางสถิติ 0.000 โดยมีค่าสัมประสิทธิ์ aged_65_older เท่ากับ 1.174e+04 หมายความว่า ถ้า aged_65_older เพิ่มขึ้น 1 หน่วย ส่งผลทำให้ total_deaths เพิ่มขึ้น 1.174e+04 หน่วย
# ### aged_70_older (x2) มีความสัมพันธ์ในทิศทางลบกับ total_deaths (Y) ที่ระดับนัยสำคัญทางสถิติ 0.000 โดยมีค่าสัมประสิทธิ์ aged_70_older เท่ากับ -1.602e+04 หมายความว่า ถ้า aged_70_older เพิ่มขึ้น 1 หน่วย ส่งผลทำให้การ total_deaths ลดลง 1.602e+04 หน่วย

# %%
model_a.params # coef
# Out:
# Intercept          0.000025
# total_cases        0.015178
# new_cases         -0.089937
# gdp_per_capita     1.343606
# life_expectancy    0.001954
# dtype: float64

# %%
model_a.pvalues #.round(10)
# Out:
# Intercept          2.518853e-122
# total_cases         0.000000e+00
# new_cases           5.432915e-06
# gdp_per_capita     2.518853e-122
# life_expectancy    2.518853e-122
# dtype: float64

# %%
model.intercept_.round(2) # sklearn
# Out:
# 72857.78

# %%
model.coef_ #.round(2)
# Out:
# array([ 1.51777032e-02, -8.99367808e-02, -3.81824095e-34,  0.00000000e+00])
