# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter #for custom number format on x and y axis
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.formula.api as sm

# %%
import io
import requests
from zipfile import ZipFile
from IPython.display import display_html

# %%
print(f'pandas  version: {pd.__version__}')
print(f'numpy   version: {np.__version__}')
# Out:
# pandas  version: 1.3.5
# numpy   version: 1.21.4

# %%
## url='http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv'
#url='https://github.com/prasertcbs/basic-dataset/raw/master/ISLR/Advertising.csv'
## df=pd.read_csv(url, index_col=0)
#df=pd.read_csv(url, usecols=[1, 2, 3, 4])
## df=pd.read_csv(url, usecols=list(range(1, 5)))
#df.head()

# %%
##การส่งข้อมูลตาราง DataFrame ไปเป็นไฟล์ .csv หรือ .xlsx
#c.to_csv('local_data.csv')
#d.to_excel('LEdata.xlsx')
#df = pd.read_excel(r'D:\HDI\HDI_data.xlsx') #, index_col='State')
#b = pd.read_csv('D:/wbdata/cancer2.csv', index_col='Entity', parse_dates=True)

# %%
# covid = pd.read_csv('D:/Python Analysis/owid-covid-data.csv')
# covid

covid = pd.read_csv('D:/Python Analysis/owid-covid-data.csv')
covid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 149520      ZWE    Africa     Zimbabwe  2021-12-19     191673.0     2106.0
# 149521      ZWE    Africa     Zimbabwe  2021-12-20     195079.0     3406.0
# 149522      ZWE    Africa     Zimbabwe  2021-12-21     197768.0     2689.0
# 149523      ZWE    Africa     Zimbabwe  2021-12-22     199404.0     1636.0
# 149524      ZWE    Africa     Zimbabwe  2021-12-23     201344.0     1940.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 149520            3504.714        4782.0         3.0                6.286
# 149521            3991.286        4805.0        23.0                9.571
# 149522            3679.429        4819.0        14.0               11.286
# 149523            3102.000        4828.0         9.0               11.857
# 149524            2755.286        4855.0        27.0               13.714
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 149520  ...             1.6          30.7                  36.791
# 149521  ...             1.6          30.7                  36.791
# 149522  ...             1.6          30.7                  36.791
# 149523  ...             1.6          30.7                  36.791
# 149524  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 149520                         1.7            61.49                    0.571
# 149521                         1.7            61.49                    0.571
# 149522                         1.7            61.49                    0.571
# 149523                         1.7            61.49                    0.571
# 149524                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 149520                                   NaN                          NaN
# 149521                                   NaN                          NaN
# 149522                                   NaN                          NaN
# 149523                                   NaN                          NaN
# 149524                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 149520               NaN                                      NaN
# 149521               NaN                                      NaN
# 149522               NaN                                      NaN
# 149523               NaN                                      NaN
# 149524               NaN                                      NaN
#
# [149525 rows x 67 columns]

# %%
# covid = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv',parse_dates=['date']) #, index_col='Entity', parse_dates=True)
# covid

# %%
covid.shape
# Out:
# (149525, 67)

# %%
covid.info()

# %%
#Save model to .csv
#data1.to_csv('D:/Face Detection/Datanew/data1.csv')
data = covid.loc[:,['date','location','total_cases','new_cases','total_deaths','life_expectancy','gdp_per_capita']].dropna() #คำสั่ง .loc ใช้เลือกข้อมูลบางคอลัมน์
data
# Out:
#               date     location  total_cases  new_cases  total_deaths  \
# 28      2020-03-23  Afghanistan         40.0        6.0           1.0
# 29      2020-03-24  Afghanistan         42.0        2.0           1.0
# 30      2020-03-25  Afghanistan         74.0       32.0           1.0
# 31      2020-03-26  Afghanistan         80.0        6.0           2.0
# 32      2020-03-27  Afghanistan         91.0       11.0           2.0
# ...            ...          ...          ...        ...           ...
# 149520  2021-12-19     Zimbabwe     191673.0     2106.0        4782.0
# 149521  2021-12-20     Zimbabwe     195079.0     3406.0        4805.0
# 149522  2021-12-21     Zimbabwe     197768.0     2689.0        4819.0
# 149523  2021-12-22     Zimbabwe     199404.0     1636.0        4828.0
# 149524  2021-12-23     Zimbabwe     201344.0     1940.0        4855.0
#
#         life_expectancy  gdp_per_capita
# 28                64.83        1803.987
# 29                64.83        1803.987
# 30                64.83        1803.987
# 31                64.83        1803.987
# 32                64.83        1803.987
# ...                 ...             ...
# 149520            61.49        1899.775
# 149521            61.49        1899.775
# 149522            61.49        1899.775
# 149523            61.49        1899.775
# 149524            61.49        1899.775
#
# [111301 rows x 7 columns]

# %%
#data5 = data5.loc[:, ['Entity','Code','Year','Breast cancer (deaths)']]
#s = data1.drop([77,140,43,119]) #,axis=0).drop([60604]) #ลบแถว
df1 = data.loc[data['date'] == '2021-12-23'].sort_values(['total_deaths'],ascending=False).drop([147610]) #.rename(columns={'Internet':'y'}) #ข้อมูล ณ วันที่ 7 ธค.2020
df1
# Out:
#               date               location  total_cases  new_cases  \
# 142056  2021-12-23          United States   51814820.0   261339.0
# 19866   2021-12-23                 Brazil   22230943.0     3774.0
# 63440   2021-12-23                  India   34772626.0     6650.0
# 88920   2021-12-23                 Mexico    3940401.0     3319.0
# 111949  2021-12-23                 Russia   10140429.0    25446.0
# ...            ...                    ...          ...        ...
# 62746   2021-12-23                Iceland      22087.0      500.0
# 113712  2021-12-23  Saint Kitts and Nevis       2815.0        0.0
# 26449   2021-12-23         Cayman Islands       8386.0      141.0
# 16620   2021-12-23                 Bhutan       2659.0        0.0
# 144468  2021-12-23                Vanuatu          7.0        0.0
#
#         total_deaths  life_expectancy  gdp_per_capita
# 142056      815423.0            78.86       54225.446
# 19866       618492.0            75.88       14103.452
# 63440       479133.0            69.66        6426.674
# 88920       298359.0            75.05       17336.469
# 111949      295296.0            72.58       24765.954
# ...              ...              ...             ...
# 62746           37.0            82.99       46482.958
# 113712          28.0            76.23       24654.385
# 26449           11.0            83.92       49903.029
# 16620            3.0            71.78        8708.597
# 144468           1.0            70.47        2921.909
#
# [181 rows x 7 columns]

# %%
df2 = df1.sort_values(['total_deaths'],ascending=False).set_index('location').head(60) #.reset_index()
df2.head(60)
# Out:
#                               date  total_cases  new_cases  total_deaths  \
# location
# United States           2021-12-23   51814820.0   261339.0      815423.0
# Brazil                  2021-12-23   22230943.0     3774.0      618492.0
# India                   2021-12-23   34772626.0     6650.0      479133.0
# Mexico                  2021-12-23    3940401.0     3319.0      298359.0
# Russia                  2021-12-23   10140429.0    25446.0      295296.0
# Peru                    2021-12-23    2271549.0     2052.0      202424.0
# United Kingdom          2021-12-23   11793109.0   122760.0      147832.0
# Indonesia               2021-12-23    4261208.0      136.0      144042.0
# Italy                   2021-12-23    5517054.0    44585.0      136245.0
# Iran                    2021-12-23    6179817.0     1932.0      131262.0
# Colombia                2021-12-23    5115194.0     2475.0      129640.0
# France                  2021-12-23    8934479.0    91608.0      122357.0
# Argentina               2021-12-23    5428957.0    13456.0      116979.0
# Germany                 2021-12-23    6978170.0    34420.0      110124.0
# Ukraine                 2021-12-23    3808612.0     7533.0      100159.0
# Poland                  2021-12-23    4017420.0    17150.0       93445.0
# South Africa            2021-12-23    3374262.0    21156.0       90662.0
# Spain                   2021-12-23    5718007.0    72912.0       89019.0
# Turkey                  2021-12-23    9249576.0    18771.0       81125.0
# Romania                 2021-12-23    1801081.0     1626.0       58463.0
# Philippines             2021-12-23    2837903.0      119.0       50981.0
# Chile                   2021-12-23    1796232.0     1482.0       38954.0
# Hungary                 2021-12-23    1237330.0     3586.0       38307.0
# Czechia                 2021-12-23    2406989.0        0.0       35288.0
# Ecuador                 2021-12-23     538218.0        0.0       33624.0
# Malaysia                2021-12-23    2731713.0     3510.0       31265.0
# Vietnam                 2021-12-23    1604712.0    16377.0       30531.0
# Bulgaria                2021-12-23     732106.0     1966.0       30436.0
# Canada                  2021-12-23    1954918.0    21929.0       30185.0
# Pakistan                2021-12-23    1292728.0      322.0       28898.0
# Belgium                 2021-12-23    2030878.0     7593.0       28110.0
# Bangladesh              2021-12-23    1582368.0      382.0       28054.0
# Tunisia                 2021-12-23     722123.0      326.0       25509.0
# Iraq                    2021-12-23    2091834.0      312.0       24108.0
# Egypt                   2021-12-23     378843.0      883.0       21510.0
# Thailand                2021-12-23    2202001.0     2940.0       21501.0
# Netherlands             2021-12-23    3032885.0    13345.0       20696.0
# Greece                  2021-12-23    1056583.0     6647.0       20198.0
# Bolivia                 2021-12-23     570876.0     1909.0       19496.0
# Myanmar                 2021-12-23     529114.0      276.0       19242.0
# Portugal                2021-12-23    1253094.0    10549.0       18840.0
# Japan                   2021-12-23    1729824.0      247.0       18382.0
# Kazakhstan              2021-12-23    1068899.0      536.0       18160.0
# Paraguay                2021-12-23     465028.0      235.0       16596.0
# Slovakia                2021-12-23    1342324.0     7418.0       16239.0
# Guatemala               2021-12-23     624866.0      322.0       16089.0
# Sweden                  2021-12-23    1273313.0     5059.0       15265.0
# Sri Lanka               2021-12-23     582149.0      554.0       14832.0
# Morocco                 2021-12-23     954199.0      475.0       14823.0
# Austria                 2021-12-23    1258377.0     2147.0       13595.0
# Georgia                 2021-12-23     918641.0     2164.0       13289.0
# Bosnia and Herzegovina  2021-12-23     286792.0      516.0       13243.0
# Serbia                  2021-12-23    1287202.0     1177.0       12518.0
# Jordan                  2021-12-23    1047953.0     2239.0       12372.0
# Croatia                 2021-12-23     686590.0     3831.0       12179.0
# Switzerland             2021-12-23    1227395.0    11451.0       12057.0
# Nepal                   2021-12-23     826664.0      241.0       11581.0
# Honduras                2021-12-23     378685.0        0.0       10423.0
# Moldova                 2021-12-23     373752.0      379.0        9575.0
# Lebanon                 2021-12-23     707123.0     1646.0        8996.0
#
#                         life_expectancy  gdp_per_capita
# location
# United States                     78.86       54225.446
# Brazil                            75.88       14103.452
# India                             69.66        6426.674
# Mexico                            75.05       17336.469
# Russia                            72.58       24765.954
# Peru                              76.74       12236.706
# United Kingdom                    81.32       39753.244
# Indonesia                         71.72       11188.744
# Italy                             83.51       35220.084
# Iran                              76.68       19082.620
# Colombia                          77.29       13254.949
# France                            82.66       38605.671
# Argentina                         76.67       18933.907
# Germany                           81.33       45229.245
# Ukraine                           72.06        7894.393
# Poland                            78.73       27216.445
# South Africa                      64.13       12294.876
# Spain                             83.56       34272.360
# Turkey                            77.69       25129.341
# Romania                           76.05       23313.199
# Philippines                       71.23        7599.188
# Chile                             80.18       22767.037
# Hungary                           76.88       26777.561
# Czechia                           79.38       32605.906
# Ecuador                           77.01       10581.936
# Malaysia                          76.16       26808.164
# Vietnam                           75.40        6171.884
# Bulgaria                          75.05       18563.307
# Canada                            82.43       44017.591
# Pakistan                          67.27        5034.708
# Belgium                           81.63       42658.576
# Bangladesh                        72.59        3523.984
# Tunisia                           76.70       10849.297
# Iraq                              70.60       15663.986
# Egypt                             71.99       10550.206
# Thailand                          77.15       16277.671
# Netherlands                       82.28       48472.545
# Greece                            82.24       24574.382
# Bolivia                           71.51        6885.829
# Myanmar                           67.13        5591.597
# Portugal                          82.05       27936.896
# Japan                             84.63       39002.223
# Kazakhstan                        73.60       24055.588
# Paraguay                          74.25        8827.010
# Slovakia                          77.54       30155.152
# Guatemala                         74.30        7423.808
# Sweden                            82.80       46949.283
# Sri Lanka                         76.98       11669.077
# Morocco                           76.68        7485.013
# Austria                           81.54       45436.686
# Georgia                           73.77        9745.079
# Bosnia and Herzegovina            77.40       11713.895
# Serbia                            76.00       14048.881
# Jordan                            74.53        8337.490
# Croatia                           78.49       22669.797
# Switzerland                       83.78       57410.166
# Nepal                             70.78        2442.804
# Honduras                          75.27        4541.795
# Moldova                           71.90        5189.972
# Lebanon                           78.93       13367.565

# %%
avg = df2['total_deaths'].mean() #.sum()/10
plt.axvline(avg, color='red', linestyle='--') 
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=18

ax = df2['total_deaths'].sort_values(ascending=True).plot(kind='barh',
                          figsize=(10, 30), #width, length
                          linewidth=25,
                          fontsize=18,
                          color=['green','red','black','c']);

ax.set_title('\n60 ประเทศที่มีผู้เสียชีวิตจากการแพร่ระบาดของโควิด 19 มากที่สุดในโลก\n', 
             fontsize=20, color='blue')
ax.set_xlabel('\nประชากรผู้เสียชีวิตเฉลี่ย (----- ค่าเฉลี่ย = 85273.8)\n', fontsize=20, color='blue');

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.01, i.get_y()+.01, \
            str(round((i.get_width()), 2)), fontsize=18, color='blue')

# invert for largest on top 
#ax.invert_yaxis()

# %%
avg.round(2)
# Out:
# 85273.8

# %%
df3 = df1.sort_values(['total_deaths'],ascending=False).set_index('location').tail(30) #.reset_index()
df3
# Out:
#                                         date  total_cases  new_cases  \
# location
# Hong Kong                         2021-12-23      12550.0        2.0
# Grenada                           2021-12-23       5948.0       15.0
# Djibouti                          2021-12-23      13555.0        9.0
# Chad                              2021-12-23       5703.0        0.0
# Aruba                             2021-12-23      17165.0      124.0
# Equatorial Guinea                 2021-12-23      13623.0        5.0
# Benin                             2021-12-23      24935.0        0.0
# Comoros                           2021-12-23       5123.0      171.0
# Guinea-Bissau                     2021-12-23       6458.0        0.0
# South Sudan                       2021-12-23      14275.0      273.0
# Seychelles                        2021-12-23      24249.0       52.0
# Tajikistan                        2021-12-23      17493.0        0.0
# Sierra Leone                      2021-12-23       6610.0       37.0
# Timor                             2021-12-23      19833.0        0.0
# Antigua and Barbuda               2021-12-23       4216.0       11.0
# Bermuda                           2021-12-23       6014.0       97.0
# Central African Republic          2021-12-23      11961.0        0.0
# Brunei                            2021-12-23      15429.0        3.0
# San Marino                        2021-12-23       7447.0       96.0
# Saint Vincent and the Grenadines  2021-12-23       5810.0        0.0
# Eritrea                           2021-12-23       7829.0       12.0
# Sao Tome and Principe             2021-12-23       3741.0        4.0
# New Zealand                       2021-12-23      13719.0       71.0
# Dominica                          2021-12-23       6520.0        0.0
# Burundi                           2021-12-23      23657.0      648.0
# Iceland                           2021-12-23      22087.0      500.0
# Saint Kitts and Nevis             2021-12-23       2815.0        0.0
# Cayman Islands                    2021-12-23       8386.0      141.0
# Bhutan                            2021-12-23       2659.0        0.0
# Vanuatu                           2021-12-23          7.0        0.0
#
#                                   total_deaths  life_expectancy  \
# location
# Hong Kong                                213.0            84.86
# Grenada                                  200.0            72.40
# Djibouti                                 189.0            67.11
# Chad                                     181.0            54.24
# Aruba                                    181.0            76.29
# Equatorial Guinea                        175.0            58.74
# Benin                                    161.0            61.77
# Comoros                                  152.0            64.32
# Guinea-Bissau                            149.0            58.32
# South Sudan                              135.0            57.85
# Seychelles                               131.0            73.40
# Tajikistan                               125.0            71.10
# Sierra Leone                             123.0            54.70
# Timor                                    122.0            69.50
# Antigua and Barbuda                      118.0            77.02
# Bermuda                                  106.0            82.59
# Central African Republic                 101.0            53.28
# Brunei                                    98.0            75.86
# San Marino                                97.0            84.97
# Saint Vincent and the Grenadines          79.0            72.53
# Eritrea                                   72.0            66.32
# Sao Tome and Principe                     57.0            70.39
# New Zealand                               49.0            82.29
# Dominica                                  44.0            75.00
# Burundi                                   38.0            61.58
# Iceland                                   37.0            82.99
# Saint Kitts and Nevis                     28.0            76.23
# Cayman Islands                            11.0            83.92
# Bhutan                                     3.0            71.78
# Vanuatu                                    1.0            70.47
#
#                                   gdp_per_capita
# location
# Hong Kong                              56054.920
# Grenada                                13593.877
# Djibouti                                2705.406
# Chad                                    1768.153
# Aruba                                  35973.781
# Equatorial Guinea                      22604.873
# Benin                                   2064.236
# Comoros                                 1413.890
# Guinea-Bissau                           1548.675
# South Sudan                             1569.888
# Seychelles                             26382.287
# Tajikistan                              2896.913
# Sierra Leone                            1390.300
# Timor                                   6570.102
# Antigua and Barbuda                    21490.943
# Bermuda                                50669.315
# Central African Republic                 661.240
# Brunei                                 71809.251
# San Marino                             56861.470
# Saint Vincent and the Grenadines       10727.146
# Eritrea                                 1510.459
# Sao Tome and Principe                   3052.714
# New Zealand                            36085.843
# Dominica                                9673.367
# Burundi                                  702.225
# Iceland                                46482.958
# Saint Kitts and Nevis                  24654.385
# Cayman Islands                         49903.029
# Bhutan                                  8708.597
# Vanuatu                                 2921.909

# %%
avg = df3['total_deaths'].mean() #.sum()/10
plt.axvline(avg, color='red', linestyle='--') 
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=18

ax = df3['total_deaths'].sort_values(ascending=True).plot(kind='barh',
                          figsize=(10, 15), #width, length
                          linewidth=25,
                          fontsize=18,
                          color=['green','red','black','c']);

ax.set_title('\n30 ประเทศที่มีผู้เสียชีวิตจากการแพร่ระบาดของโควิด 19 น้อยที่สุดในโลก\n', 
             fontsize=20, color='blue')
ax.set_xlabel('\nประชากรผู้เสียชีวิตเฉลี่ย (----- ค่าเฉลี่ย = 35.5)\n', fontsize=20, color='blue');
ax.set_ylabel('ประเทศ\n', fontsize=20, color='blue');

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.01, i.get_y()+.01, \
            str(round((i.get_width()), 2)), fontsize=18, color='blue')

# invert for largest on top 
ax.invert_yaxis()

# %%
avg.round(2)
# Out:
# 105.87

# %%
# 10 Countries in AEC
AEC = df1.loc[df1['location'].isin(['Singapore','Indonesia','Thailand','Myanmar','Vietnam','Brunei','Laos','Cambodia','Malaysia','Philippines'])].set_index('location') #.reset_index() 
AEC
# Out:
#                    date  total_cases  new_cases  total_deaths  \
# location
# Indonesia    2021-12-23    4261208.0      136.0      144042.0
# Philippines  2021-12-23    2837903.0      119.0       50981.0
# Malaysia     2021-12-23    2731713.0     3510.0       31265.0
# Vietnam      2021-12-23    1604712.0    16377.0       30531.0
# Thailand     2021-12-23    2202001.0     2940.0       21501.0
# Myanmar      2021-12-23     529114.0      276.0       19242.0
# Cambodia     2021-12-23     120434.0        4.0        3006.0
# Singapore    2021-12-23     277042.0      322.0         820.0
# Laos         2021-12-23     101865.0        0.0         288.0
# Brunei       2021-12-23      15429.0        3.0          98.0
#
#              life_expectancy  gdp_per_capita
# location
# Indonesia              71.72       11188.744
# Philippines            71.23        7599.188
# Malaysia               76.16       26808.164
# Vietnam                75.40        6171.884
# Thailand               77.15       16277.671
# Myanmar                67.13        5591.597
# Cambodia               69.82        3645.070
# Singapore              83.62       85535.383
# Laos                   67.92        6397.360
# Brunei                 75.86       71809.251

# %%
avg = AEC['total_deaths'].mean() #.sum()/10
plt.axvline(avg, color='red', linestyle='--') 
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=18

ax = AEC['total_deaths'].sort_values(ascending=True).plot(kind='barh',
                          figsize=(8, 5), #width, length
                          linewidth=25,
                          fontsize=18,
                          color=['green','red','black','c']);

ax.set_title('\n กลุ่มประเทศ AEC ที่มีผู้เสียชีวิตจากการแพร่ระบาดของโควิด 19\n', 
             fontsize=20, color='blue')
ax.set_xlabel('\nประชากรผู้เสียชีวิตเฉลี่ย (----- ค่าเฉลี่ย = 30177.4)\n', fontsize=20, color='blue');
ax.set_ylabel('ประเทศ\n', fontsize=20, color='blue');

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.01, i.get_y()+.01, \
            str(round((i.get_width()), 2)), fontsize=18, color='blue')

# invert for largest on top 
#ax.invert_yaxis()

# %%
avg
# Out:
# 30177.4

# %%
co = pd.read_csv('D:/Python Analysis/owid-covid-data.csv')
co
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 149520      ZWE    Africa     Zimbabwe  2021-12-19     191673.0     2106.0
# 149521      ZWE    Africa     Zimbabwe  2021-12-20     195079.0     3406.0
# 149522      ZWE    Africa     Zimbabwe  2021-12-21     197768.0     2689.0
# 149523      ZWE    Africa     Zimbabwe  2021-12-22     199404.0     1636.0
# 149524      ZWE    Africa     Zimbabwe  2021-12-23     201344.0     1940.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 149520            3504.714        4782.0         3.0                6.286
# 149521            3991.286        4805.0        23.0                9.571
# 149522            3679.429        4819.0        14.0               11.286
# 149523            3102.000        4828.0         9.0               11.857
# 149524            2755.286        4855.0        27.0               13.714
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 149520  ...             1.6          30.7                  36.791
# 149521  ...             1.6          30.7                  36.791
# 149522  ...             1.6          30.7                  36.791
# 149523  ...             1.6          30.7                  36.791
# 149524  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 149520                         1.7            61.49                    0.571
# 149521                         1.7            61.49                    0.571
# 149522                         1.7            61.49                    0.571
# 149523                         1.7            61.49                    0.571
# 149524                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 149520                                   NaN                          NaN
# 149521                                   NaN                          NaN
# 149522                                   NaN                          NaN
# 149523                                   NaN                          NaN
# 149524                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 149520               NaN                                      NaN
# 149521               NaN                                      NaN
# 149522               NaN                                      NaN
# 149523               NaN                                      NaN
# 149524               NaN                                      NaN
#
# [149525 rows x 67 columns]

# %%
# co = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv',parse_dates=['date']) #, index_col='Entity', parse_dates=True)
# co

# %%
co.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149525 entries, 0 to 149524
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    149525 non-null  object
#  1   continent                                   140505 non-null  object
#  2   location                                    149525 non-null  object
#  3   date                                        149525 non-null  object
#  4   total_cases                                 146874 non-null  float64
#  5   new_cases                                   146868 non-null  float64
#  6   new_cases_smoothed                          145723 non-null  float64
#  7   total_deaths                                129842 non-null  float64
#  8   new_deaths                                  130037 non-null  float64
#  9   new_deaths_smoothed                         145723 non-null  float64
#  10  total_cases_per_million                     146188 non-null  float64
#  11  new_cases_per_million                       146182 non-null  float64
#  12  new_cases_smoothed_per_million              145042 non-null  float64
#  13  total_deaths_per_million                    129169 non-null  float64
#  14  new_deaths_per_million                      129364 non-null  float64
#  15  new_deaths_smoothed_per_million             145042 non-null  float64
#  16  reproduction_rate                           112750 non-null  float64
#  17  icu_patients                                17049 non-null   float64
#  18  icu_patients_per_million                    17049 non-null   float64
#  19  hosp_patients                               20170 non-null   float64
#  20  hosp_patients_per_million                   20170 non-null   float64
#  21  weekly_icu_admissions                       3875 non-null    float64
#  22  weekly_icu_admissions_per_million           3875 non-null    float64
#  23  weekly_hosp_admissions                      7889 non-null    float64
#  24  weekly_hosp_admissions_per_million          7889 non-null    float64
#  25  new_tests                                   59597 non-null   float64
#  26  total_tests                                 59774 non-null   float64
#  27  total_tests_per_thousand                    59774 non-null   float64
#  28  new_tests_per_thousand                      59597 non-null   float64
#  29  new_tests_smoothed                          72648 non-null   float64
#  30  new_tests_smoothed_per_thousand             71962 non-null   float64
#  31  positive_rate                               67786 non-null   float64
#  32  tests_per_case                              67124 non-null   float64
#  33  tests_units                                 74093 non-null   object
#  34  total_vaccinations                          37621 non-null   float64
#  35  people_vaccinated                           36159 non-null   float64
#  36  people_fully_vaccinated                     33363 non-null   float64
#  37  total_boosters                              10950 non-null   float64
#  38  new_vaccinations                            31155 non-null   float64
#  39  new_vaccinations_smoothed                   68690 non-null   float64
#  40  total_vaccinations_per_hundred              37621 non-null   float64
#  41  people_vaccinated_per_hundred               36159 non-null   float64
#  42  people_fully_vaccinated_per_hundred         33363 non-null   float64
#  43  total_boosters_per_hundred                  10950 non-null   float64
#  44  new_vaccinations_smoothed_per_million       68690 non-null   float64
#  45  new_people_vaccinated_smoothed              67552 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  67552 non-null   float64
#  47  stringency_index                            117290 non-null  float64
#  48  population                                  148522 non-null  float64
#  49  population_density                          133114 non-null  float64
#  50  median_age                                  124235 non-null  float64
#  51  aged_65_older                               122884 non-null  float64
#  52  aged_70_older                               123567 non-null  float64
#  53  gdp_per_capita                              124626 non-null  float64
#  54  extreme_poverty                             82288 non-null   float64
#  55  cardiovasc_death_rate                       123254 non-null  float64
#  56  diabetes_prevalence                         129565 non-null  float64
#  57  female_smokers                              95478 non-null   float64
#  58  male_smokers                                94102 non-null   float64
#  59  handwashing_facilities                      61718 non-null   float64
#  60  hospital_beds_per_thousand                  111366 non-null  float64
#  61  life_expectancy                             139549 non-null  float64
#  62  human_development_index                     122729 non-null  float64
#  63  excess_mortality_cumulative_absolute        5125 non-null    float64
#  64  excess_mortality_cumulative                 5125 non-null    float64
#  65  excess_mortality                            5125 non-null    float64
#  66  excess_mortality_cumulative_per_million     5125 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 76.4+ MB

# %%
co.isnull().sum().head(30)
# Out:
# iso_code                                   0
# continent                               9020
# location                                   0
# date                                       0
# total_cases                             2651
# new_cases                               2657
# new_cases_smoothed                      3802
# total_deaths                           19683
# new_deaths                             19488
# new_deaths_smoothed                     3802
# total_cases_per_million                 3337
# new_cases_per_million                   3343
# new_cases_smoothed_per_million          4483
# total_deaths_per_million               20356
# new_deaths_per_million                 20161
# new_deaths_smoothed_per_million         4483
# reproduction_rate                      36775
# icu_patients                          132476
# icu_patients_per_million              132476
# hosp_patients                         129355
# hosp_patients_per_million             129355
# weekly_icu_admissions                 145650
# weekly_icu_admissions_per_million     145650
# weekly_hosp_admissions                141636
# weekly_hosp_admissions_per_million    141636
# new_tests                              89928
# total_tests                            89751
# total_tests_per_thousand               89751
# new_tests_per_thousand                 89928
# new_tests_smoothed                     76877
# dtype: int64

# %%
m = co.columns
i=1
for n in range(len(m)):
    print('%d' %i, m[n])
    i += 1
# Out:
# 1 iso_code
# 2 continent
# 3 location
# 4 date
# 5 total_cases
# 6 new_cases
# 7 new_cases_smoothed
# 8 total_deaths
# 9 new_deaths
# 10 new_deaths_smoothed
# 11 total_cases_per_million
# 12 new_cases_per_million
# 13 new_cases_smoothed_per_million
# 14 total_deaths_per_million
# 15 new_deaths_per_million
# 16 new_deaths_smoothed_per_million
# 17 reproduction_rate
# 18 icu_patients
# 19 icu_patients_per_million
# 20 hosp_patients
# 21 hosp_patients_per_million
# 22 weekly_icu_admissions
# 23 weekly_icu_admissions_per_million
# 24 weekly_hosp_admissions
# 25 weekly_hosp_admissions_per_million
# 26 new_tests
# 27 total_tests
# 28 total_tests_per_thousand
# 29 new_tests_per_thousand
# 30 new_tests_smoothed
# 31 new_tests_smoothed_per_thousand
# 32 positive_rate
# 33 tests_per_case
# 34 tests_units
# 35 total_vaccinations
# 36 people_vaccinated
# 37 people_fully_vaccinated
# 38 total_boosters
# 39 new_vaccinations
# 40 new_vaccinations_smoothed
# 41 total_vaccinations_per_hundred
# 42 people_vaccinated_per_hundred
# 43 people_fully_vaccinated_per_hundred
# 44 total_boosters_per_hundred
# 45 new_vaccinations_smoothed_per_million
# 46 new_people_vaccinated_smoothed
# 47 new_people_vaccinated_smoothed_per_hundred
# 48 stringency_index
# 49 population
# 50 population_density
# 51 median_age
# 52 aged_65_older
# 53 aged_70_older
# 54 gdp_per_capita
# 55 extreme_poverty
# 56 cardiovasc_death_rate
# 57 diabetes_prevalence
# 58 female_smokers
# 59 male_smokers
# 60 handwashing_facilities
# 61 hospital_beds_per_thousand
# 62 life_expectancy
# 63 human_development_index
# 64 excess_mortality_cumulative_absolute
# 65 excess_mortality_cumulative
# 66 excess_mortality
# 67 excess_mortality_cumulative_per_million

# %% [markdown]
# ## Simple Linear Regression

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
print(f'pandas  version: {pd.__version__}')
print(f'numpy   version: {np.__version__}')
print(f'seaborn version: {sns.__version__}')
# Out:
# pandas  version: 1.3.5
# numpy   version: 1.21.4
# seaborn version: 0.11.2

# %%
df = co[['total_deaths','life_expectancy','aged_65_older','aged_70_older','gdp_per_capita','new_cases','population_density']].dropna()
df
# Out:
#         total_deaths  life_expectancy  aged_65_older  aged_70_older  \
# 28               1.0            64.83          2.581          1.337
# 29               1.0            64.83          2.581          1.337
# 30               1.0            64.83          2.581          1.337
# 31               2.0            64.83          2.581          1.337
# 32               2.0            64.83          2.581          1.337
# ...              ...              ...            ...            ...
# 149520        4782.0            61.49          2.822          1.882
# 149521        4805.0            61.49          2.822          1.882
# 149522        4819.0            61.49          2.822          1.882
# 149523        4828.0            61.49          2.822          1.882
# 149524        4855.0            61.49          2.822          1.882
#
#         gdp_per_capita  new_cases  population_density
# 28            1803.987        6.0              54.422
# 29            1803.987        2.0              54.422
# 30            1803.987       32.0              54.422
# 31            1803.987        6.0              54.422
# 32            1803.987       11.0              54.422
# ...                ...        ...                 ...
# 149520        1899.775     2106.0              42.729
# 149521        1899.775     3406.0              42.729
# 149522        1899.775     2689.0              42.729
# 149523        1899.775     1636.0              42.729
# 149524        1899.775     1940.0              42.729
#
# [107816 rows x 7 columns]

# %%
plt.figure(figsize=(16, 9))
sns.lmplot(x='gdp_per_capita', y='life_expectancy', data=df, ci=None);

# %%
sns.jointplot(x='gdp_per_capita', y='life_expectancy', data=df, kind='reg', ci=None,color='green');

# %%
df
# Out:
#         total_deaths  life_expectancy  aged_65_older  aged_70_older  \
# 28               1.0            64.83          2.581          1.337
# 29               1.0            64.83          2.581          1.337
# 30               1.0            64.83          2.581          1.337
# 31               2.0            64.83          2.581          1.337
# 32               2.0            64.83          2.581          1.337
# ...              ...              ...            ...            ...
# 149520        4782.0            61.49          2.822          1.882
# 149521        4805.0            61.49          2.822          1.882
# 149522        4819.0            61.49          2.822          1.882
# 149523        4828.0            61.49          2.822          1.882
# 149524        4855.0            61.49          2.822          1.882
#
#         gdp_per_capita  new_cases  population_density
# 28            1803.987        6.0              54.422
# 29            1803.987        2.0              54.422
# 30            1803.987       32.0              54.422
# 31            1803.987        6.0              54.422
# 32            1803.987       11.0              54.422
# ...                ...        ...                 ...
# 149520        1899.775     2106.0              42.729
# 149521        1899.775     3406.0              42.729
# 149522        1899.775     2689.0              42.729
# 149523        1899.775     1636.0              42.729
# 149524        1899.775     1940.0              42.729
#
# [107816 rows x 7 columns]

# %%
#import statsmodels.api as sm
import statsmodels.formula.api as smf

slr = smf.ols(formula='life_expectancy ~ gdp_per_capita', data=df).fit()
print(slr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.457
# Method:                 Least Squares   F-statistic:                 9.074e+04
# Date:                Wed, 29 Dec 2021   Prob (F-statistic):               0.00
# Time:                        13:27:59   Log-Likelihood:            -3.3753e+05
# No. Observations:              107816   AIC:                         6.751e+05
# Df Residuals:                  107814   BIC:                         6.751e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         67.9479      0.024   2879.897      0.000      67.902      67.994
# gdp_per_capita     0.0003   8.49e-07    301.223      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                    11270.721   Durbin-Watson:                   0.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15151.322
# Skew:                          -0.907   Prob(JB):                         0.00
# Kurtosis:                       3.282   Cond. No.                     3.89e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.89e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### ถ้าค่า p (P>|t|) < 0.05 (ค่า p น้อยกว่า 0.05) แสดงว่ามีความสัมพันธ์กัน คือคือตัวแปรต้น (X หรือเหตุ) เป็นสาเหตุ/ส่งผลต่อตัวแปรตาม (Y หรือผล) เช่น กินจุ (เหตุ) ทำให้อ้วน (ผล) ขณะเดียวกัน อ้วน (เหตุ) ทำให้เป็นโรคความดัน เบาหวาน (ผล) เป็นต้น
# ### ถ้าค่า p (P>|t|) > 0.05 (ค่า p มากกว่า 0.05) แสดงว่าไม่มีความสัมพันธ์กัน คือคือตัวแปรต้น (X หรือเหตุ) ไม่เป็นสาเหตุ/ไม่ส่งผลต่อตัวแปรตาม (Y หรือผล) เช่น กินจุ (เหตุ) แต่ก็ไม่ทำให้อ้วน (ผล) ขณะเดียวกัน อ้วน (เหตุ) ไม่ทำให้เป็นโรคความดัน เบาหวาน (ผล) เป็นต้น
# ### ค่าอย่างมีนัยสำคัญทางสถิติที่..... ถ้าค่า p < 0.05 แต่ > 0.01 อย่างมีนัยสำคัญทางสถิติที่ 0.05, ถ้าค่า p < 0.01 แต่ > 0.001 อย่างมีนัยสำคัญทางสถิติที่ 0.01, ถ้าค่า p < 0.001 อย่างมีนัยสำคัญทางสถิติที่ 0.000

# %% [markdown]
# ### การอธิบายค่าสัมประสิทธิ์ถดถอย (coef) ถ้าค่าเป็นบวก (0.8963) หมายความว่า x1 (ตัวแปรอิสระ/ต้น: เหตุ) เพิ่มขึ้น ส่งผลให้ Y (ตัวแปรตาม: ผล) เพิ่มตามไปด้วย ขณะเดียวกัน ถ้าค่าเป็นลบ (-0.8963) หมายความว่า x1 (ตัวแปรอิสระ: เหตุ) เพิ่มขึ้น ส่งผลให้ Y (ตัวแปรตาม: ผล) ลดลง

# %% [markdown]
# ## แบบจำลองในการศึกษา
# ### Y = a + b1x1 + e
# ### กำหนดให้
# #### a = ค่าคงที่ความถดถอยพหุ
# #### b1 = ค่าสัมประสิทธิถดถอยของตัวแปรอิสระ (ตัวแปรต้น)
# #### Y = life_expectancy อายุคาดเฉลี่ย
# #### x1 = gdp_per_capita
# #### e = ค่าความคลาดเคลื่อน

# %% [markdown]
# ### การอธิบายแปลผล เอาเฉพาะตัวที่มีนัยสำคัญทางสถิติ คือค่า p < 0.05 เท่านั้นมาอธิบายแปลผล
# ### ผลการศึกษาพบว่า gdp_per_capita (x1) มีความสัมพันธ์ในทิศทางบวกกับ life_expectancy (Y) ที่ระดับนัยสำคัญทางสถิติ 0.000 โดยมีค่าสัมประสิทธิ์ gdp_per_capita เท่ากับ 0.0003 หมายความว่า ถ้า gdp_per_capita เพิ่มขึ้น 1 หน่วย ส่งผลทำให้ life_expectancy เพิ่มขึ้น 0.0003 หน่วย

# %% [markdown]
# ## การประเมินโมเดล Regression

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
X = df[['gdp_per_capita']]
y = df.life_expectancy
# y = df[['life_expectancy']]

# %%
y
# Out:
# 28        64.83
# 29        64.83
# 30        64.83
# 31        64.83
# 32        64.83
#           ...
# 149520    61.49
# 149521    61.49
# 149522    61.49
# 149523    61.49
# 149524    61.49
# Name: life_expectancy, Length: 107816, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_.round(4)
# Out:
# array([0.0003])

# %%
model.intercept_.round(0)
# Out:
# 68.0

# %%
print(
    f'ค่าสัมประสิทธิ์ถดถอยเท่ากับ {model.coef_.round(5)} มีค่าเป็นบวก หมายความว่า หากรัฐมีนโยบายกระตุ้นเศรษฐกิจให้จีดีพีต่อหัวเพิ่มขึ้น ส่งผลทำให้อายุคาดเฉลี่ยของประชากรเพิ่มขึ้น 0.02561 ปี (0.0002561*100) ',
    f'ค่า intercept (ค่าคงที่) เท่ากับ {model.intercept_.round(0)} หมายความว่า ถ้าหากรัฐไม่มีการกระตุ้นเศรษฐกิจคือไม่ทำอะไรเลย อายุคาดเฉลี่ยของประชากรอยู่ที่ 68 ปี',
    sep='\n')
# Out:
# ค่าสัมประสิทธิ์ถดถอยเท่ากับ [0.00026] มีค่าเป็นบวก หมายความว่า หากรัฐมีนโยบายกระตุ้นเศรษฐกิจให้จีดีพีต่อหัวเพิ่มขึ้น ส่งผลทำให้อายุคาดเฉลี่ยของประชากรเพิ่มขึ้น 0.02561 ปี (0.0002561*100)
# ค่า intercept (ค่าคงที่) เท่ากับ 68.0 หมายความว่า ถ้าหากรัฐไม่มีการกระตุ้นเศรษฐกิจคือไม่ทำอะไรเลย อายุคาดเฉลี่ยของประชากรอยู่ที่ 68 ปี

# %%
#ค่าร้อยละของความถูกต้องแม่นยำ
# ค่าเข้าใกล้ 1 จะดี แต่ถ้าเข้าใกล้ 0 ไม่ดี 
print('R square =',model.score(X,y).round(3))
# Out:
# R square = 0.457

# %%
y_predict = model.predict(X)

# %%
#ค่าร้อยละของความถูกต้องแม่นยำ
# ถ้าค่า R square เข้าใกล้ 1 จะดี 
print('R square =', r2_score(y,y_predict).round(3))
# Out:
# R square = 0.457

# %%
#ค่าเฉลี่ยความคลาดเคลื่อนยกกำลังสอง
# ถ้าค่า MSE เข้าใกล้ 0 จะดี แต่ถ้าาเข้าใกล้ 1 ไม่ค่อยดี 
mean_squared_error(y,y_predict).round(3)
# Out:
# 30.672

# %%
#ค่าเฉลี่ยความคลาดเคลื่อนสัมบูรณ์
# ถ้าค่า MAE เข้าใกล้ 0 จะดี แต่ถ้าาเข้าใกล้ 1 ไม่ค่อยดี 
mean_absolute_error(y,y_predict).round(3)
# Out:
# 4.499

# %% [markdown]
# ## การแบ่งข้อมูลเพื่อใช้ในการ train_test_split แบบรัน Regression

# %%
X = df[['gdp_per_capita']]
y = df.life_expectancy

# %%
X.describe().round(0)
# Out:
#        gdp_per_capita
# count        107816.0
# mean          19436.0
# std           19871.0
# min             661.0
# 25%            4467.0
# 50%           13255.0
# 75%           27937.0
# max          116936.0

# %%
y.describe().round(0)
# Out:
# count    107816.0
# mean         73.0
# std           8.0
# min          53.0
# 25%          67.0
# 50%          74.0
# 75%          78.0
# max          85.0
# Name: life_expectancy, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test).round(3)
# Out:
# 0.455

# %% [markdown]
# ## การพยากรณ์ Simple linear regression แบบวิธีที่ 1

# %%
#np.arange(start,stop,step)
#.reshape(-1, 1) -1 หมายถึง กีแถวไม่รู้ให้เครื่องกำหนดให้ 1 หมายถึง 1 คอลัมน์

actual = np.arange(661,116936,2000).reshape(-1, 1)
actual
# Out:
# array([[   661],
#        [  2661],
#        [  4661],
#        [  6661],
#        [  8661],
#        [ 10661],
#        [ 12661],
#        [ 14661],
#        [ 16661],
#        [ 18661],
#        [ 20661],
#        [ 22661],
#        [ 24661],
#        [ 26661],
#        [ 28661],
#        [ 30661],
#        [ 32661],
#        [ 34661],
#        [ 36661],
#        [ 38661],
#        [ 40661],
#        [ 42661],
#        [ 44661],
#        [ 46661],
#        [ 48661],
#        [ 50661],
#        [ 52661],
#        [ 54661],
#        [ 56661],
#        [ 58661],
#        [ 60661],
#        [ 62661],
#        [ 64661],
#        [ 66661],
#        [ 68661],
#        [ 70661],
#        [ 72661],
#        [ 74661],
#        [ 76661],
#        [ 78661],
#        [ 80661],
#        [ 82661],
#        [ 84661],
#        [ 86661],
#        [ 88661],
#        [ 90661],
#        [ 92661],
#        [ 94661],
#        [ 96661],
#        [ 98661],
#        [100661],
#        [102661],
#        [104661],
#        [106661],
#        [108661],
#        [110661],
#        [112661],
#        [114661],
#        [116661]])

# %%
y_pred = model.predict(actual).reshape(-1, 1).round(0)
y_pred
# Out:
# C:\Users\Techatach\anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[68.],
#        [69.],
#        [69.],
#        [70.],
#        [70.],
#        [71.],
#        [71.],
#        [72.],
#        [72.],
#        [73.],
#        [73.],
#        [74.],
#        [74.],
#        [75.],
#        [75.],
#        [76.],
#        [76.],
#        [77.],
#        [77.],
#        [78.],
#        [78.],
#        [79.],
#        [79.],
#        [80.],
#        [80.],
#        [81.],
#        [81.],
#        [82.],
#        [82.],
#        [83.],
#        [83.],
#        [84.],
#        [84.],
#        [85.],
#        [86.],
#        [86.],
#        [87.],
#        [87.],
#        [88.],
#        [88.],
#        [89.],
#        [89.],
#        [90.],
#        [90.],
#        [91.],
#        [91.],
#        [92.],
#        [92.],
#        [93.],
#        [93.],
#        [94.],
#        [94.],
#        [95.],
#        [95.],
#        [96.],
#        [96.],
#        [97.],
#        [97.],
#        [98.]])

# %%
data = pd.DataFrame(actual) #.round(0)
##renaming in columns
data = data.rename(columns={0:'Actual_GDP'})
data
# Out:
#     Actual_GDP
# 0          661
# 1         2661
# 2         4661
# 3         6661
# 4         8661
# 5        10661
# 6        12661
# 7        14661
# 8        16661
# 9        18661
# 10       20661
# 11       22661
# 12       24661
# 13       26661
# 14       28661
# 15       30661
# 16       32661
# 17       34661
# 18       36661
# 19       38661
# 20       40661
# 21       42661
# 22       44661
# 23       46661
# 24       48661
# 25       50661
# 26       52661
# 27       54661
# 28       56661
# 29       58661
# 30       60661
# 31       62661
# 32       64661
# 33       66661
# 34       68661
# 35       70661
# 36       72661
# 37       74661
# 38       76661
# 39       78661
# 40       80661
# 41       82661
# 42       84661
# 43       86661
# 44       88661
# 45       90661
# 46       92661
# 47       94661
# 48       96661
# 49       98661
# 50      100661
# 51      102661
# 52      104661
# 53      106661
# 54      108661
# 55      110661
# 56      112661
# 57      114661
# 58      116661

# %%
y_hat = pd.DataFrame(y_pred) #.round(0)
##renaming in columns
y_hat = y_hat.rename(columns={0:'Predict_LE'})
y_hat
# Out:
#     Predict_LE
# 0         68.0
# 1         69.0
# 2         69.0
# 3         70.0
# 4         70.0
# 5         71.0
# 6         71.0
# 7         72.0
# 8         72.0
# 9         73.0
# 10        73.0
# 11        74.0
# 12        74.0
# 13        75.0
# 14        75.0
# 15        76.0
# 16        76.0
# 17        77.0
# 18        77.0
# 19        78.0
# 20        78.0
# 21        79.0
# 22        79.0
# 23        80.0
# 24        80.0
# 25        81.0
# 26        81.0
# 27        82.0
# 28        82.0
# 29        83.0
# 30        83.0
# 31        84.0
# 32        84.0
# 33        85.0
# 34        86.0
# 35        86.0
# 36        87.0
# 37        87.0
# 38        88.0
# 39        88.0
# 40        89.0
# 41        89.0
# 42        90.0
# 43        90.0
# 44        91.0
# 45        91.0
# 46        92.0
# 47        92.0
# 48        93.0
# 49        93.0
# 50        94.0
# 51        94.0
# 52        95.0
# 53        95.0
# 54        96.0
# 55        96.0
# 56        97.0
# 57        97.0
# 58        98.0

# %%
df = pd.concat([data,y_hat],axis=1).round(0)
#df.to_csv('D:\Python Analysis\DataRegression\APdata.csv')
df
# Out:
#     Actual_GDP  Predict_LE
# 0          661        68.0
# 1         2661        69.0
# 2         4661        69.0
# 3         6661        70.0
# 4         8661        70.0
# 5        10661        71.0
# 6        12661        71.0
# 7        14661        72.0
# 8        16661        72.0
# 9        18661        73.0
# 10       20661        73.0
# 11       22661        74.0
# 12       24661        74.0
# 13       26661        75.0
# 14       28661        75.0
# 15       30661        76.0
# 16       32661        76.0
# 17       34661        77.0
# 18       36661        77.0
# 19       38661        78.0
# 20       40661        78.0
# 21       42661        79.0
# 22       44661        79.0
# 23       46661        80.0
# 24       48661        80.0
# 25       50661        81.0
# 26       52661        81.0
# 27       54661        82.0
# 28       56661        82.0
# 29       58661        83.0
# 30       60661        83.0
# 31       62661        84.0
# 32       64661        84.0
# 33       66661        85.0
# 34       68661        86.0
# 35       70661        86.0
# 36       72661        87.0
# 37       74661        87.0
# 38       76661        88.0
# 39       78661        88.0
# 40       80661        89.0
# 41       82661        89.0
# 42       84661        90.0
# 43       86661        90.0
# 44       88661        91.0
# 45       90661        91.0
# 46       92661        92.0
# 47       94661        92.0
# 48       96661        93.0
# 49       98661        93.0
# 50      100661        94.0
# 51      102661        94.0
# 52      104661        95.0
# 53      106661        95.0
# 54      108661        96.0
# 55      110661        96.0
# 56      112661        97.0
# 57      114661        97.0
# 58      116661        98.0

# %%
# df.to_excel('D:\Python Analysis\DataRegression\APdata.xlsx')
# df.to_csv('D:\Python Analysis\DataRegression\APdata.csv')

data = pd.read_csv('D:\Python Analysis\DataRegression\APdata.csv') 
df = data.drop(['Unnamed: 0'], axis=1) #ลบคอลัมน์
df
# Out:
#     Actual_GDP  Predict_LE
# 0          661        68.0
# 1         2661        69.0
# 2         4661        69.0
# 3         6661        70.0
# 4         8661        70.0
# 5        10661        71.0
# 6        12661        71.0
# 7        14661        72.0
# 8        16661        72.0
# 9        18661        73.0
# 10       20661        73.0
# 11       22661        74.0
# 12       24661        74.0
# 13       26661        75.0
# 14       28661        75.0
# 15       30661        76.0
# 16       32661        76.0
# 17       34661        77.0
# 18       36661        77.0
# 19       38661        78.0
# 20       40661        78.0
# 21       42661        79.0
# 22       44661        79.0
# 23       46661        80.0
# 24       48661        80.0
# 25       50661        81.0
# 26       52661        81.0
# 27       54661        82.0
# 28       56661        82.0
# 29       58661        83.0
# 30       60661        83.0
# 31       62661        84.0
# 32       64661        84.0
# 33       66661        85.0
# 34       68661        86.0
# 35       70661        86.0
# 36       72661        87.0
# 37       74661        87.0
# 38       76661        88.0
# 39       78661        88.0
# 40       80661        89.0
# 41       82661        89.0
# 42       84661        90.0
# 43       86661        90.0
# 44       88661        91.0
# 45       90661        91.0
# 46       92661        92.0
# 47       94661        92.0
# 48       96661        93.0
# 49       98661        93.0
# 50      100661        94.0
# 51      102661        94.0
# 52      104661        95.0
# 53      106661        95.0
# 54      108661        96.0
# 55      110661        96.0
# 56      112661        97.0
# 57      114661        97.0
# 58      116661        98.0

# %% [markdown]
# ## การพยากรณ์ Simple linear regression แบบวิธีที่ 2

# %%
#np.linspace(start, stop, num=20, endpoint=True, retstep=False, dtype=None, axis=0)

act2 = np.linspace(661,116936,20).reshape(-1, 1).round(0)
act2
# Out:
# array([[   661.],
#        [  6781.],
#        [ 12900.],
#        [ 19020.],
#        [ 25140.],
#        [ 31260.],
#        [ 37379.],
#        [ 43499.],
#        [ 49619.],
#        [ 55739.],
#        [ 61858.],
#        [ 67978.],
#        [ 74098.],
#        [ 80218.],
#        [ 86337.],
#        [ 92457.],
#        [ 98577.],
#        [104697.],
#        [110816.],
#        [116936.]])

# %%
y_pred2 = model.predict(act2).reshape(-1, 1).round(0)
y_pred2
# Out:
# C:\Users\Techatach\anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[68.],
#        [70.],
#        [71.],
#        [73.],
#        [74.],
#        [76.],
#        [78.],
#        [79.],
#        [81.],
#        [82.],
#        [84.],
#        [85.],
#        [87.],
#        [88.],
#        [90.],
#        [92.],
#        [93.],
#        [95.],
#        [96.],
#        [98.]])

# %%
df1 = pd.DataFrame(act2) #.round(0)
##renaming in columns
df1 = df1.rename(columns={0:'Actual_GDP'})
df1
# Out:
#     Actual_GDP
# 0        661.0
# 1       6781.0
# 2      12900.0
# 3      19020.0
# 4      25140.0
# 5      31260.0
# 6      37379.0
# 7      43499.0
# 8      49619.0
# 9      55739.0
# 10     61858.0
# 11     67978.0
# 12     74098.0
# 13     80218.0
# 14     86337.0
# 15     92457.0
# 16     98577.0
# 17    104697.0
# 18    110816.0
# 19    116936.0

# %%
y_hat2 = pd.DataFrame(y_pred2) #.round(0)
##renaming in columns
y_hat2 = y_hat2.rename(columns={0:'Predict_LE'})
y_hat2
# Out:
#     Predict_LE
# 0         68.0
# 1         70.0
# 2         71.0
# 3         73.0
# 4         74.0
# 5         76.0
# 6         78.0
# 7         79.0
# 8         81.0
# 9         82.0
# 10        84.0
# 11        85.0
# 12        87.0
# 13        88.0
# 14        90.0
# 15        92.0
# 16        93.0
# 17        95.0
# 18        96.0
# 19        98.0

# %%
df2 = pd.concat([df1,y_hat2],axis=1).round(0)
df2
# Out:
#     Actual_GDP  Predict_LE
# 0        661.0        68.0
# 1       6781.0        70.0
# 2      12900.0        71.0
# 3      19020.0        73.0
# 4      25140.0        74.0
# 5      31260.0        76.0
# 6      37379.0        78.0
# 7      43499.0        79.0
# 8      49619.0        81.0
# 9      55739.0        82.0
# 10     61858.0        84.0
# 11     67978.0        85.0
# 12     74098.0        87.0
# 13     80218.0        88.0
# 14     86337.0        90.0
# 15     92457.0        92.0
# 16     98577.0        93.0
# 17    104697.0        95.0
# 18    110816.0        96.0
# 19    116936.0        98.0

# %% [markdown]
# ## การพยากรณ์ Simple linear regression แบบวิธีที่ 3

# %%
#np.linspace(start, stop, num=20, endpoint=True, retstep=False, dtype=None, axis=0)

dag = pd.DataFrame(np.linspace(661,116936,20), columns=['Actual_GDP']).round(0)
dag
# Out:
#     Actual_GDP
# 0        661.0
# 1       6781.0
# 2      12900.0
# 3      19020.0
# 4      25140.0
# 5      31260.0
# 6      37379.0
# 7      43499.0
# 8      49619.0
# 9      55739.0
# 10     61858.0
# 11     67978.0
# 12     74098.0
# 13     80218.0
# 14     86337.0
# 15     92457.0
# 16     98577.0
# 17    104697.0
# 18    110816.0
# 19    116936.0

# %%
dm = model.predict(dag).reshape(-1,1).round(0)
dm = pd.DataFrame(dm) 

##renaming in columns
y_hat3 = dm.rename(columns={0:'Predict_LE'})
y_hat3
# Out:
# C:\Users\Techatach\anaconda3\lib\site-packages\sklearn\base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Actual_GDP
# Feature names seen at fit time, yet now missing:
# - gdp_per_capita
#
#   warnings.warn(message, FutureWarning)
#     Predict_LE
# 0         68.0
# 1         70.0
# 2         71.0
# 3         73.0
# 4         74.0
# 5         76.0
# 6         78.0
# 7         79.0
# 8         81.0
# 9         82.0
# 10        84.0
# 11        85.0
# 12        87.0
# 13        88.0
# 14        90.0
# 15        92.0
# 16        93.0
# 17        95.0
# 18        96.0
# 19        98.0

# %%
df3 = pd.concat([dag,y_hat3],axis=1).round(0)
df3
# Out:
#     Actual_GDP  Predict_LE
# 0        661.0        68.0
# 1       6781.0        70.0
# 2      12900.0        71.0
# 3      19020.0        73.0
# 4      25140.0        74.0
# 5      31260.0        76.0
# 6      37379.0        78.0
# 7      43499.0        79.0
# 8      49619.0        81.0
# 9      55739.0        82.0
# 10     61858.0        84.0
# 11     67978.0        85.0
# 12     74098.0        87.0
# 13     80218.0        88.0
# 14     86337.0        90.0
# 15     92457.0        92.0
# 16     98577.0        93.0
# 17    104697.0        95.0
# 18    110816.0        96.0
# 19    116936.0        98.0

# %% [markdown]
# ## กลุ่มประเทศ AEC

# %%
import pandas as pd

df1 = pd.read_csv('D:/Python Analysis/gdp-per-capita-worldbank.csv')
df2 = pd.read_csv('D:/Python Analysis/life-expectancy.csv')

df = df1.merge(df2)
df
# Out:
#            Entity Code  Year  GDP per capita  Life expectancy
# 0     Afghanistan  AFG  2002     1189.784668           56.784
# 1     Afghanistan  AFG  2003     1235.810063           57.271
# 2     Afghanistan  AFG  2004     1200.278013           57.772
# 3     Afghanistan  AFG  2005     1286.793659           58.290
# 4     Afghanistan  AFG  2006     1315.789117           58.826
# ...           ...  ...   ...             ...              ...
# 5525     Zimbabwe  ZWE  2015     3198.982129           59.534
# 5526     Zimbabwe  ZWE  2016     3173.610829           60.294
# 5527     Zimbabwe  ZWE  2017     3274.611198           60.812
# 5528     Zimbabwe  ZWE  2018     3341.665418           61.195
# 5529     Zimbabwe  ZWE  2019     3027.656038           61.490
#
# [5530 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5530 entries, 0 to 5529
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Entity           5530 non-null   object
#  1   Code             5530 non-null   object
#  2   Year             5530 non-null   int64
#  3   GDP per capita   5530 non-null   float64
#  4   Life expectancy  5530 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 259.2+ KB

# %%
c = df.Entity.unique()
len(c)
# Out:
# 194

# %%
# 10 Countries in AEC
AEC = df.loc[df['Entity'].isin(['Singapore','Indonesia','Thailand','Myanmar','Vietnam','Brunei','Laos','Cambodia','Malaysia','Philippines'])].set_index('Entity') #.reset_index() 
AEC
# Out:
#         Code  Year  GDP per capita  Life expectancy
# Entity
# Brunei   BRN  1990    71232.789430           70.185
# Brunei   BRN  1991    71405.378120           70.439
# Brunei   BRN  1992    72705.728040           70.696
# Brunei   BRN  1993    70908.808190           70.951
# Brunei   BRN  1994    71176.341930           71.207
# ...      ...   ...             ...              ...
# Vietnam  VNM  2015     6438.259854           75.110
# Vietnam  VNM  2016     6767.778832           75.172
# Vietnam  VNM  2017     7155.443187           75.241
# Vietnam  VNM  2018     7585.943155           75.317
# Vietnam  VNM  2019     8041.178384           75.400
#
# [297 rows x 4 columns]

# %%
AEC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, Brunei to Vietnam
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Code             297 non-null    object
#  1   Year             297 non-null    int64
#  2   GDP per capita   297 non-null    float64
#  3   Life expectancy  297 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 11.6+ KB

# %%
#Save model to .csv
#data.to_csv('D:/Face Detection/Datanew/data1.csv')
d = AEC.loc[:,['GDP per capita','Life expectancy']].dropna() #คำสั่ง .loc ใช้เลือกข้อมูลบางคอลัมน์
d
# Out:
#          GDP per capita  Life expectancy
# Entity
# Brunei     71232.789430           70.185
# Brunei     71405.378120           70.439
# Brunei     72705.728040           70.696
# Brunei     70908.808190           70.951
# Brunei     71176.341930           71.207
# ...                 ...              ...
# Vietnam     6438.259854           75.110
# Vietnam     6767.778832           75.172
# Vietnam     7155.443187           75.241
# Vietnam     7585.943155           75.317
# Vietnam     8041.178384           75.400
#
# [297 rows x 2 columns]

# %%
X = d[['GDP per capita']]
y = d[['Life expectancy']]

# %%
X.describe().round(0)
# Out:
#        GDP per capita
# count           297.0
# mean          19325.0
# std           25549.0
# min             607.0
# 25%            3546.0
# 50%            6699.0
# 75%           18453.0
# max           98412.0

# %%
y.describe().round(0)
# Out:
#        Life expectancy
# count            297.0
# mean              70.0
# std                7.0
# min               53.0
# 25%               66.0
# 50%               70.0
# 75%               74.0
# max               84.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test).round(3)
# Out:
# 0.466

# %%
#np.linspace(start, stop, num=20, endpoint=True, retstep=False, dtype=None, axis=0)
import numpy as np

d_th = pd.DataFrame(np.linspace(19325,100000,20), columns=['Actual_GDP']).round(0)
d_th
# Out:
#     Actual_GDP
# 0      19325.0
# 1      23571.0
# 2      27817.0
# 3      32063.0
# 4      36309.0
# 5      40555.0
# 6      44801.0
# 7      49047.0
# 8      53293.0
# 9      57539.0
# 10     61786.0
# 11     66032.0
# 12     70278.0
# 13     74524.0
# 14     78770.0
# 15     83016.0
# 16     87262.0
# 17     91508.0
# 18     95754.0
# 19    100000.0

# %%
dm = model.predict(d_th).reshape(-1,1).round(0)
dm = pd.DataFrame(dm) 

##renaming in columns
y_hat = dm.rename(columns={0:'Predict_LE'})
y_hat
# Out:
# C:\Users\Techatach\anaconda3\lib\site-packages\sklearn\base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Actual_GDP
# Feature names seen at fit time, yet now missing:
# - GDP per capita
#
#   warnings.warn(message, FutureWarning)
#     Predict_LE
# 0         70.0
# 1         71.0
# 2         71.0
# 3         72.0
# 4         73.0
# 5         73.0
# 6         74.0
# 7         75.0
# 8         75.0
# 9         76.0
# 10        77.0
# 11        77.0
# 12        78.0
# 13        79.0
# 14        79.0
# 15        80.0
# 16        81.0
# 17        81.0
# 18        82.0
# 19        83.0

# %%
df = pd.concat([d_th,y_hat],axis=1).round(0)
df
# Out:
#     Actual_GDP  Predict_LE
# 0      19325.0        70.0
# 1      23571.0        71.0
# 2      27817.0        71.0
# 3      32063.0        72.0
# 4      36309.0        73.0
# 5      40555.0        73.0
# 6      44801.0        74.0
# 7      49047.0        75.0
# 8      53293.0        75.0
# 9      57539.0        76.0
# 10     61786.0        77.0
# 11     66032.0        77.0
# 12     70278.0        78.0
# 13     74524.0        79.0
# 14     78770.0        79.0
# 15     83016.0        80.0
# 16     87262.0        81.0
# 17     91508.0        81.0
# 18     95754.0        82.0
# 19    100000.0        83.0

# %% [markdown]
# ## Thailand

# %%
import pandas as pd

df1 = pd.read_csv('D:/Python Analysis/gdp-per-capita-worldbank.csv')
df2 = pd.read_csv('D:/Python Analysis/life-expectancy.csv')

df = df1.merge(df2)
df
# Out:
#            Entity Code  Year  GDP per capita  Life expectancy
# 0     Afghanistan  AFG  2002     1189.784668           56.784
# 1     Afghanistan  AFG  2003     1235.810063           57.271
# 2     Afghanistan  AFG  2004     1200.278013           57.772
# 3     Afghanistan  AFG  2005     1286.793659           58.290
# 4     Afghanistan  AFG  2006     1315.789117           58.826
# ...           ...  ...   ...             ...              ...
# 5525     Zimbabwe  ZWE  2015     3198.982129           59.534
# 5526     Zimbabwe  ZWE  2016     3173.610829           60.294
# 5527     Zimbabwe  ZWE  2017     3274.611198           60.812
# 5528     Zimbabwe  ZWE  2018     3341.665418           61.195
# 5529     Zimbabwe  ZWE  2019     3027.656038           61.490
#
# [5530 rows x 5 columns]

# %%
th = df.loc[df['Entity'].isin(['Thailand'])].reset_index() #.set_index('location') #.reset_index() 
th
# Out:
#     index    Entity Code  Year  GDP per capita  Life expectancy
# 0    4901  Thailand  THA  1990     7102.056264           70.248
# 1    4902  Thailand  THA  1991     7619.036169           70.300
# 2    4903  Thailand  THA  1992     8152.500092           70.281
# 3    4904  Thailand  THA  1993     8745.552017           70.239
# 4    4905  Thailand  THA  1994     9358.708398           70.202
# 5    4906  Thailand  THA  1995    10017.933670           70.191
# 6    4907  Thailand  THA  1996    10467.454610           70.215
# 7    4908  Thailand  THA  1997    10059.376810           70.267
# 8    4909  Thailand  THA  1998     9180.019523           70.348
# 9    4910  Thailand  THA  1999     9489.818324           70.463
# 10   4911  Thailand  THA  2000     9809.622370           70.623
# 11   4912  Thailand  THA  2001    10053.815400           70.832
# 12   4913  Thailand  THA  2002    10583.761860           71.089
# 13   4914  Thailand  THA  2003    11260.158110           71.389
# 14   4915  Thailand  THA  2004    11886.324620           71.728
# 15   4916  Thailand  THA  2005    12304.402080           72.099
# 16   4917  Thailand  THA  2006    12837.877920           72.499
# 17   4918  Thailand  THA  2007    13460.060560           72.916
# 18   4919  Thailand  THA  2008    13620.532370           73.341
# 19   4920  Thailand  THA  2009    13458.526710           73.766
# 20   4921  Thailand  THA  2010    14399.044510           74.184
# 21   4922  Thailand  THA  2011    14450.478830           74.593
# 22   4923  Thailand  THA  2012    15424.544270           74.992
# 23   4924  Thailand  THA  2013    15767.360810           75.378
# 24   4925  Thailand  THA  2014    15854.131860           75.747
# 25   4926  Thailand  THA  2015    16285.386570           76.091
# 26   4927  Thailand  THA  2016    16782.098670           76.403
# 27   4928  Thailand  THA  2017    17422.952350           76.683
# 28   4929  Thailand  THA  2018    18095.736570           76.931
# 29   4930  Thailand  THA  2019    18453.469820           77.150

# %%
X = th[['GDP per capita']]
y = th[['Life expectancy']]

# %%
X.describe().round()
# Out:
#        GDP per capita
# count            30.0
# mean          12413.0
# std            3299.0
# min            7102.0
# 25%            9862.0
# 50%           12095.0
# 75%           15181.0
# max           18453.0

# %%
y.describe().round(0)
# Out:
#        Life expectancy
# count             30.0
# mean              73.0
# std                2.0
# min               70.0
# 25%               70.0
# 50%               72.0
# 75%               75.0
# max               77.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test).round(3)
# Out:
# 0.968

# %%
model.coef_.round(5)
# Out:
# array([[0.00074]])

# %%
model.intercept_.round(2)
# Out:
# array([63.52])

# %%
print(
    f'ค่าสัมประสิทธิ์ (slope) {model.coef_.round(5)} มีค่าเป็นบวก หมายความว่า หากรัฐมีนโยบายกระตุ้นเศรษฐกิจให้จีดีพีต่อหัวเพิ่มขึ้น ส่งผลทำให้อายุคาดเฉลี่ยของประชากรเพิ่มขึ้น 0.074 ปี (0.00073804*100) ',
    f'ค่า intercept (ค่าคงที่) เท่ากับ {model.intercept_.round(0)} หมายความว่า ถ้าหากรัฐไม่มีการกระตุ้นเศรษฐกิจคือไม่ทำอะไรเลย อายุคาดเฉลี่ยของประชากรอยู่ที่ 64 ปี',
    sep='\n')
# Out:
# ค่าสัมประสิทธิ์ (slope) [[0.00074]] มีค่าเป็นบวก หมายความว่า หากรัฐมีนโยบายกระตุ้นเศรษฐกิจให้จีดีพีต่อหัวเพิ่มขึ้น ส่งผลทำให้อายุคาดเฉลี่ยของประชากรเพิ่มขึ้น 0.074 ปี (0.00073804*100)
# ค่า intercept (ค่าคงที่) เท่ากับ [64.] หมายความว่า ถ้าหากรัฐไม่มีการกระตุ้นเศรษฐกิจคือไม่ทำอะไรเลย อายุคาดเฉลี่ยของประชากรอยู่ที่ 64 ปี

# %%
#np.linspace(start, stop, num=20, endpoint=True, retstep=False, dtype=None, axis=0)
import numpy as np

d_th = pd.DataFrame(np.linspace(12413,50000,20), columns=['Actual_GDP']).round(0)
d_th
# Out:
#     Actual_GDP
# 0      12413.0
# 1      14391.0
# 2      16370.0
# 3      18348.0
# 4      20326.0
# 5      22304.0
# 6      24283.0
# 7      26261.0
# 8      28239.0
# 9      30217.0
# 10     32196.0
# 11     34174.0
# 12     36152.0
# 13     38130.0
# 14     40109.0
# 15     42087.0
# 16     44065.0
# 17     46043.0
# 18     48022.0
# 19     50000.0

# %%
dm = model.predict(d_th).reshape(-1,1).round(0)
dm = pd.DataFrame(dm) 

##renaming in columns
y_hat = dm.rename(columns={0:'Predict_LE'})
y_hat
# Out:
# C:\Users\Techatach\anaconda3\lib\site-packages\sklearn\base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Actual_GDP
# Feature names seen at fit time, yet now missing:
# - GDP per capita
#
#   warnings.warn(message, FutureWarning)
#     Predict_LE
# 0         73.0
# 1         74.0
# 2         76.0
# 3         77.0
# 4         79.0
# 5         80.0
# 6         81.0
# 7         83.0
# 8         84.0
# 9         86.0
# 10        87.0
# 11        89.0
# 12        90.0
# 13        92.0
# 14        93.0
# 15        95.0
# 16        96.0
# 17        98.0
# 18        99.0
# 19       100.0

# %%
df = pd.concat([d_th,y_hat],axis=1).round(0)
df
# Out:
#     Actual_GDP  Predict_LE
# 0      12413.0        73.0
# 1      14391.0        74.0
# 2      16370.0        76.0
# 3      18348.0        77.0
# 4      20326.0        79.0
# 5      22304.0        80.0
# 6      24283.0        81.0
# 7      26261.0        83.0
# 8      28239.0        84.0
# 9      30217.0        86.0
# 10     32196.0        87.0
# 11     34174.0        89.0
# 12     36152.0        90.0
# 13     38130.0        92.0
# 14     40109.0        93.0
# 15     42087.0        95.0
# 16     44065.0        96.0
# 17     46043.0        98.0
# 18     48022.0        99.0
# 19     50000.0       100.0
