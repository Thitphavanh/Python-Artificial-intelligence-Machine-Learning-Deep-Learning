# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# #การแปลงข้อมูล class คอลัมน์ location ให้เป็นตัวเลข
# from sklearn.preprocessing import LabelEncoder
# y_le = LabelEncoder()
# y = y_le.fit_transform(df.Species)
# df['class'] = y 
# y

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# ##การแบ่งข้อมูลให้เป็น Features และ Class โดยการใช้คำสั่่ง iloc ดังนี้
# X = df.iloc[:, :-2].values 
# y = df.iloc[:, -1].values

#การแบ่งข้อมูลให้เป็น Features และ Class อีกวิธีหนึ่ง ดังนี้ 
X = df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']] #.values 
y = df[['Species']] #.values

# %%
y
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
#การแบ่งข้อมูลสำหรับ train และ test โมเดล ดังนี้ 

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                   test_size=0.2, random_state=48)

# %%
#การสร้างโมเดล Multiclass Logistic เพื่อการพยากรณ์

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
y_predict.reshape(-1,1)
# Out:
# C:\Users\Techatach\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
# ...

# %%
#การป้อนข้อมูลพยากรณ์
pred1 = [[5.1,3.5,1.4,0.2],
         [6.7,3.0,5.2,2.3],
         [5.5,2.3,4.0,1.3],
         [5.9,3.0,5.1,1.8]]
         
db = model.predict(pred1)

i = 1
for m in range(len(db)):
    print('%d' %i, db[m])
    i += 1
# Out:
# 1 Iris-setosa
# 2 Iris-virginica
# 3 Iris-versicolor
# 4 Iris-virginica
# C:\Users\Techatach\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
#การแปลงข้อมูล array ให้เป็นตาราง dataframe ดังนี้ 

import pandas as pd
pred = y_predict.reshape(-1,1)
ds = pd.DataFrame(pred) #.head(10)
data = ds.rename(columns={0:'ข้อมูลพยากรณ์'})
data
# Out:
#       ข้อมูลพยากรณ์
# 0   Iris-versicolor
# 1   Iris-versicolor
# 2    Iris-virginica
# 3       Iris-setosa
# 4    Iris-virginica
# 5    Iris-virginica
# 6       Iris-setosa
# 7    Iris-virginica
# 8       Iris-setosa
# 9   Iris-versicolor
# 10   Iris-virginica
# 11      Iris-setosa
# 12      Iris-setosa
# 13   Iris-virginica
# 14  Iris-versicolor
# 15  Iris-versicolor
# 16      Iris-setosa
# 17  Iris-versicolor
# 18  Iris-versicolor
# 19   Iris-virginica
# 20      Iris-setosa
# 21   Iris-virginica
# 22   Iris-virginica
# 23  Iris-versicolor
# 24   Iris-virginica
# 25      Iris-setosa
# 26      Iris-setosa
# 27   Iris-virginica
# 28   Iris-virginica
# 29  Iris-versicolor

# %%
#เปรียบเทียบกับข้อมูลจริงว่าพยากรณ์ถูกต้องไหม
actual = y_test.reset_index()
data2 = actual.rename(columns={'Species':'ข้อมูลจริง'})
data2
# Out:
#     index       ข้อมูลจริง
# 0      96  Iris-versicolor
# 1      73  Iris-versicolor
# 2     134   Iris-virginica
# 3      41      Iris-setosa
# 4      70  Iris-versicolor
# 5     116   Iris-virginica
# 6      19      Iris-setosa
# 7     138   Iris-virginica
# 8      33      Iris-setosa
# 9      89  Iris-versicolor
# 10    137   Iris-virginica
# 11     36      Iris-setosa
# 12     20      Iris-setosa
# 13    126   Iris-virginica
# 14     87  Iris-versicolor
# 15     56  Iris-versicolor
# 16     11      Iris-setosa
# 17     62  Iris-versicolor
# 18     72  Iris-versicolor
# 19    120   Iris-virginica
# 20      8      Iris-setosa
# 21    147   Iris-virginica
# 22     77  Iris-versicolor
# 23     86  Iris-versicolor
# 24    129   Iris-virginica
# 25      4      Iris-setosa
# 26     31      Iris-setosa
# 27    136   Iris-virginica
# 28    132   Iris-virginica
# 29     88  Iris-versicolor

# %%
#ตารางเปรียบเทียบข้อมูลจริงและการพยากรณ์

total = pd.concat([data2,data],axis=1).round(0)
tm = total.drop(['index'], axis=1) #ลบคอลัมน์ index
tm
# Out:
#          ข้อมูลจริง    ข้อมูลพยากรณ์
# 0   Iris-versicolor  Iris-versicolor
# 1   Iris-versicolor  Iris-versicolor
# 2    Iris-virginica   Iris-virginica
# 3       Iris-setosa      Iris-setosa
# 4   Iris-versicolor   Iris-virginica
# 5    Iris-virginica   Iris-virginica
# 6       Iris-setosa      Iris-setosa
# 7    Iris-virginica   Iris-virginica
# 8       Iris-setosa      Iris-setosa
# 9   Iris-versicolor  Iris-versicolor
# 10   Iris-virginica   Iris-virginica
# 11      Iris-setosa      Iris-setosa
# 12      Iris-setosa      Iris-setosa
# 13   Iris-virginica   Iris-virginica
# 14  Iris-versicolor  Iris-versicolor
# 15  Iris-versicolor  Iris-versicolor
# 16      Iris-setosa      Iris-setosa
# 17  Iris-versicolor  Iris-versicolor
# 18  Iris-versicolor  Iris-versicolor
# 19   Iris-virginica   Iris-virginica
# 20      Iris-setosa      Iris-setosa
# 21   Iris-virginica   Iris-virginica
# 22  Iris-versicolor   Iris-virginica
# 23  Iris-versicolor  Iris-versicolor
# ...

# %%
#ตารางเปรียบเทียบการจำแนกข้อมูลจริงและการพยากรณ์
x_test = X_test.reset_index()
dm = x_test.drop(['index'], axis=1) #ลบคอลัมน์ index
td = pd.concat([dm, tm],axis=1) #.round(0)
td
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm       ข้อมูลจริง  \
# 0             5.7           2.9            4.2           1.3  Iris-versicolor
# 1             6.1           2.8            4.7           1.2  Iris-versicolor
# 2             6.1           2.6            5.6           1.4   Iris-virginica
# 3             4.5           2.3            1.3           0.3      Iris-setosa
# 4             5.9           3.2            4.8           1.8  Iris-versicolor
# 5             6.5           3.0            5.5           1.8   Iris-virginica
# 6             5.1           3.8            1.5           0.3      Iris-setosa
# 7             6.0           3.0            4.8           1.8   Iris-virginica
# 8             5.5           4.2            1.4           0.2      Iris-setosa
# 9             5.5           2.5            4.0           1.3  Iris-versicolor
# 10            6.4           3.1            5.5           1.8   Iris-virginica
# ...

# %% [markdown]
# #### การประเมินโมเดลว่ามีความแม่นยำกี่เปอร์เซ็นต์ (%)

# %%
y_targets = df['Species'].unique()
y_targets
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

print('Accuracy Score: {:.2f}'.format(accuracy_score(y_test, y_predict)))
#print('Accuracy Score:',accuracy_score(y_test, y_predict).round(2))
print(classification_report(y_test, y_predict, target_names=y_targets))
cm = confusion_matrix(y_test, y_predict)
print(cm)

#pip install scikit-plot
import scikitplot as skplot
plt.rcParams['figure.figsize'] = 6,6 #10 x 10
skplot.metrics.plot_confusion_matrix(y_test, y_predict)
plt.show()
# Out:
# Accuracy Score: 0.93
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       1.00      0.82      0.90        11
#  Iris-virginica       0.83      1.00      0.91        10
#
#        accuracy                           0.93        30
#       macro avg       0.94      0.94      0.94        30
#    weighted avg       0.94      0.93      0.93        30
#
# [[ 9  0  0]
#  [ 0  9  2]
#  [ 0  0 10]]
